# %% [markdown]
# ## 模型加载 Large-v3

# %%
import torch
from transformers import pipeline

device = "cuda:0" if torch.cuda.is_available() else "cpu"

pipe = pipeline(
    "automatic-speech-recognition",
    model="/opt/Data/ModelWeight/openai/whisper-large-v3",
    chunk_length_s=30,
    device=device
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
prediction = pipe("/opt/WorkSpace/whisper/voice/FindingNemo.aac", batch_size=4, return_timestamps=True, generate_kwargs={"language": "zh", "task": "transcribe"})
dickValue = prediction["chunks"]
for key in dickValue:
    print(str(key["timestamp"][0]) + " - " + str(key["timestamp"][1]) + "\t:" + key["text"])
# Out:
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 0.0 - 3.72	:海底小组队
# 3.72 - 4.8	:各就各位
# 4.8 - 7.18	:万岁
# 7.18 - 9.12	:万岁
# 9.12 - 47.32	:一生海底小动队与海底风暴
# 47.32 - 58.44	:这应该差不多了
# 58.44 - 60.52	:虎沙艇又换人一新了
# 60.52 - 61.28	:怎么样
# 61.28 - 62.9	:兔兔兔
# 62.9 - 64.92	:它看上去比原来还棒呢
# 64.92 - 65.6	:瞧瞧这个我还新安装了这个涡轮按钮我开心了怎么样哎 兔兔兔它看上去比原来还棒呢
# 65.6 - 66.6	:瞧瞧这个
# 66.6 - 69.6	:我还新安装了这个涡轮按钮
# 69.6 - 72.6	:在遇到危急情况的时候
# 72.6 - 75.6	:这个涡轮可以给舰艇更多的力量
# 75.6 - 76.6	:是的
# 76.6 - 78.6	:还有比赛的时候
# 80.6 - 83.6	:我已经等不及要带它出去试驾了
# 83.6 - 84.6	:我的小可爱
# 84.6 - 86.32	:开启章鱼宝藏门
# 86.32 - 88.04	:好吧
# 88.04 - 91.8	:但是
# 91.8 - 92.66	:光基
# 92.66 - 95.12	:记得只能在紧急的情况下
# 95.12 - 96.7	:才能使用涡轮按钮
# 140.46 - 143.72	:我得确定这玩意儿最好有效队长 你来看看这个风暴探测仪上好像有些大动静
# 144.0 - 149.0	:看这个,风暴探测仪上好像有些大动静
# 151.0 - 160.0	:启动章鱼探测器
# 164.0 - 166.24	:是一场大风暴呢,而且正朝着我们而来达西西 启动章鱼警报
# 166.24 - 170.1	:海底小纵队去基地总部
# 181.48 - 182.46	:海底小纵队
# 182.46 - 185.46	:我们必须在风暴来临之前做好准备
# 185.46 - 188.56	:如果这场风暴在海面上很大
# 188.56 - 190.8	:它在海底也会很大的
# 190.8 - 193.88	:大西西
# 193.88 - 195.86	:风暴靠近的时候通知大家
# 195.86 - 196.72	:明白 队长
# 196.72 - 197.8	:皮医生
# 197.8 - 199.2	:关闭所有外部通道
# 199.2 - 200.48	:明白 队长
# 209.02 - 210.0	:图图兔收起起章鱼宝车架明白,队长
# 210.52 - 221.5	:呱唧,马上关闭引擎,然后我们可以
# 221.5 - 222.76	:呱唧
# 222.76 - 225.0	:呱唧到底去哪了我们可以用空地引擎然后我们可以呃呃
# 225.0 - 226.0	:呃
# 226.0 - 227.0	:呃
# 227.0 - 228.0	:呃
# 228.0 - 229.0	:呃
# 229.0 - 230.0	:呃
# 230.0 - 231.0	:呃
# 231.0 - 232.0	:呃
# 232.0 - 233.0	:呃
# 233.0 - 234.0	:呃
# 234.0 - 235.0	:呃
# 235.0 - 236.0	:呃
# 236.0 - 237.0	:呃
# 237.0 - 238.0	:呃
# 238.0 - 239.0	:呃
# 239.0 - 240.0	:呃
# 240.0 - 241.0	:呃
# 241.0 - 242.0	:呃
# 242.0 - 243.0	:呃
# 243.0 - 244.0	:呃
# 244.0 - 279.48	:呃呃呃呃呃哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦哦                                                                                                               停
# 279.48 - 281.18	:龙虾宝宝有危险
# 286.64 - 288.0	:别担心小龙虾我来帮你
# 288.0 - 296.62	:呱唧 我是达西西
# 296.62 - 298.68	:你必须现在回到章鱼堡
# 298.68 - 300.8	:危险的风暴就要来了
# 300.8 - 304.2	:喂喂 你能听见我吗
# 304.2 - 305.0	:好了谢谢你 海底小纵队这没什么我来就要来了喂喂你能听见我吗
# 305.0 - 307.0	:哎 好了
# 307.0 - 309.0	:谢谢你 海底小纵队
# 309.0 - 310.0	:这没什么
# 310.0 - 312.0	:别再离开你的家人了
# 312.0 - 314.0	:哇
# 314.0 - 316.0	:好大一家子
# 316.0 - 317.0	:你们都要到哪去
# 317.0 - 319.0	:从珊瑚礁往深海游
# 319.0 - 322.0	:这样我们在大风暴中会更安全
# 322.0 - 324.0	:大风暴
# 324.0 - 325.76	:什么大风暴从这边来的大风暴 先生如果真的打风暴装会更安全大风暴什么大风暴
# 325.76 - 328.76	:从这边来的大风暴 先生
# 328.76 - 330.0	:如果真的有风暴
# 330.0 - 333.0	:我得确定在深湖礁的同伴都安全
# 333.0 - 335.0	:再见了 小伙伴
# 336.0 - 337.76	:作为一只龙虾宝宝
# 337.76 - 339.76	:你的钳子很大
# 339.76 - 341.76	:谢谢你 先生 再见
# 342.76 - 344.76	:妈妈
# 344.76 - 346.14	:她说我有一堆大钳子
# 346.14 - 348.0	:那很棒啊 亲爱的
# 348.0 - 350.9	:华吉 你能听到我吗
# 350.9 - 351.9	:万分紧急
# 351.9 - 353.56	:风暴就要来了
# 353.56 - 356.74	:你必须在风暴到来之前赶回章驴堡
# 356.74 - 357.92	:好的
# 357.92 - 359.54	:让我马上检查一下
# 359.54 - 361.64	:珊瑚礁上的同伴们是不是都安全
# 361.64 - 362.86	:别担心 队长
# 362.86 - 366.0	:不会在风暴来临之前赶回来的
# 367.0 - 369.0	:队长 风暴来得很快
# 369.0 - 371.0	:还有十分钟就要到了
# 371.0 - 372.0	:挂机
# 372.0 - 375.0	:我们会尽可能保持章鱼堡舱门开启
# 375.0 - 376.0	:谢谢 队长
# 382.0 - 402.64	:海南有危险
# 403.24 - 405.3	:刮鸡还有九分钟风暴就要来了
# 405.3 - 406.14	:知道了
# 412.04 - 412.96	:抓住你了
# 412.96 - 415.0	:还有八分钟
# 415.0 - 417.54	:马上就好
# 417.54 - 424.38	:都好了
# 424.38 - 426.12	:我现在回家
# 426.12 - 427.28	:再见
# 427.28 - 430.0	:挂机只有七分钟了
# 442.54 - 443.9	:加油啊 虎沙厅
# 443.9 - 445.6	:你可以的
# 445.6 - 449.52	:是时候使用涡轮动力了
# 463.36 - 463.94	:呱唧
# 463.94 - 465.18	:你能听见我吗现在马上回张玉宝你能听见我吗呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃
# 465.18 - 465.26	:呃
# 465.26 - 465.36	:呃
# 465.36 - 465.46	:呃
# 465.46 - 465.62	:呃
# 465.62 - 465.64	:呃
# 465.64 - 465.66	:呃
# 465.66 - 465.76	:呃
# 465.76 - 465.82	:呃
# 465.82 - 466.24	:呃
# 466.24 - 466.82	:呃
# 466.82 - 466.86	:呃
# 466.86 - 467.24	:呃
# 467.24 - 467.42	:呃
# 467.42 - 467.82	:呃
# 467.82 - 468.26	:呃
# 468.26 - 468.42	:呃
# 468.42 - 468.56	:呃
# 468.56 - 482.58	:呃
# 482.58 - 483.56	:呃
# 483.56 - 483.62	:呃
# 483.62 - 484.62	:呃
# 484.62 - 488.0	:呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃呃我去追他
# 490.0 - 491.0	:等我们一起进入章鱼堡马上关闭舱门
# 499.0 - 517.14	:我快追上你来挂机释放拖绳
# 517.14 - 519.18	:抓到了
# 519.18 - 520.7	:队长
# 520.7 - 521.98	:还有三分钟
# 521.98 - 522.94	:风暴就要来了
# 522.94 - 555.4	:我们能行龙虾托生
# 555.4 - 558.12	:可能有用
# 558.12 - 560.76	:队长
# 560.76 - 563.12	:只有一分钟的时间了
# 563.12 - 564.12	:谢谢达西西
# 564.12 - 566.58	:水中的漫境交易宝舱门队长我们必有一分钟的时间了谢谢达西西水中的漫进章鱼宝舱门
# 566.58 - 568.82	:队长 我们必须关门了
# 568.82 - 572.0	:等等 保持章鱼宝舱门开启
# 584.0 - 585.28	:我们就要进来了
# 585.28 - 587.44	:准备关闭张英宝舱门
# 587.44 - 588.84	:十
# 588.84 - 590.32	:九
# 590.32 - 591.6	:八
# 591.6 - 592.24	:七
# 592.24 - 593.78	:抓好了 小龙虾们
# 593.78 - 594.6	:六
# 594.6 - 596.0	:五
# 596.0 - 597.28	:四
# 597.28 - 598.96	:三
# 598.96 - 600.58	:二
# 600.58 - 602.42	:一
# 602.42 - 604.66	:太好了
# 604.66 - 605.32	:你可真把我们吓了一跳二一成功了
# 605.32 - 609.18	:你可真把我们吓了一跳
# 609.18 - 612.32	:如果没有这只小龙虾的大钳子
# 612.32 - 614.88	:我们就回不来了
# 614.88 - 617.92	:这没什么
# 617.92 - 623.12	:这真是一个躲避风暴的好地方
# 623.12 - 627.54	:这的确是一次了不起的世价呱唧
# 627.54 - 630.56	:看起来我还有好多事情要做
# 630.56 - 632.32	:但是首先
# 632.32 - 635.14	:请问你们谁想要一杯热巧克力呢
# 635.14 - 637.54	:好的
# 637.54 - 638.66	:我也要
# 638.66 - 647.7	:再给我来一些棉花糖海底小统队集合
# 647.7 - 648.2	:挂机
# 648.2 - 648.56	:提升
# 648.56 - 649.04	:进攻
# 649.04 - 649.48	:拿起
# 649.48 - 650.48	:速度
# 650.48 - 653.16	:点罗吧
# 653.16 - 654.86	:挂机
# 654.86 - 655.98	:启动
# 655.98 - 657.54	:海底报告
# 657.54 - 663.58	:记住
# 663.58 - 665.86	:小石龙下住在地面上
# 665.86 - 666.1	:是的
# 666.1 - 666.72	:没错
# 666.72 - 667.14	:明白
# 667.14 - 669.36	:他们不用拥在地上跑
# 669.36 - 669.86	:是的
# 669.86 - 670.46	:没错
# 670.46 - 672.96	:他们各自小声地鼓掌
# 672.96 - 674.24	:好地宝宝
# 674.24 - 676.4	:能扩大选择且强壮
# 676.4 - 678.0	:好地宝宝
# 678.0 - 680.42	:怀天气他们不害怕
# 680.42 - 680.7	:是的
# 680.7 - 681.22	:没错
# 681.22 - 681.66	:明白
# 681.66 - 683.12	:就往神处涌
# 683.12 - 684.8	:团结力量大
# 684.8 - 685.82	:又是来知道没错就往身处用团结力量大跳起来
# 685.82 - 690.42	:龙虾加油
# 690.42 - 691.46	:就是龙虾
# 691.46 - 692.5	:就是龙虾
# 692.5 - 694.04	:好嘞 棒棒
# 694.04 - 695.8	:好嘞 棒棒
# 695.8 - 696.62	:好嘞 棒棒
# 696.62 - 699.34	:任务到此结束
# 699.34 - 700.86	:海底小统队
# 700.86 - 701.36	:小心
# 701.36 - None	:我们下次探险再见

# %%
prediction = pipe("/opt/WorkSpace/whisper/voice/c++对象模型探索课程详细介绍.aac",
                  batch_size=4,
                  return_timestamps=True,
                  generate_kwargs={"language": "en", "task": "translate"})
dickValue = prediction["chunks"]
for key in dickValue:
    print(str(key["timestamp"][0]) + " - " + str(key["timestamp"][1]) + "\t:" + key["text"])
# Out:
# 0.0 - 2.48	: Hello, everyone
# 2.48 - 5.28	: Nice to meet you
# 5.28 - 8.96	: This class is a new class from the teacher
# 8.96 - 12.04	: The name is Xijiajia object model exploration
# 12.04 - 14.64	: It can also be said to be the fourth class of the teacher
# 14.64 - 19.16	: The first three classes are the first class is the west language entrance
# 19.16 - 22.68	: The second class is our Xijiajia from entry to the end
# 22.68 - 25.42	: Xijiajia 11 14 17 The third class is Xijiajia from entry to completion Xijiajia 11 14 17
# 25.44 - 27.68	: The third class is Xijiajia 11
# 27.68 - 29.72	: The occurrence and the multi-line
# 29.72 - 33.32	: So this class is called Xijiajia object model exploration
# 33.32 - 35.66	: It's the fourth class of the teacher
# 35.66 - 36.68	: So this class
# 36.68 - 39.44	: He's a little bit of a challenge
# 39.44 - 41.62	: There's also a little bit of a fun lesson
# 42.86 - 67.02	: So what we're talking about now is the first chapter of this class The first chapter of the exploration of the first chapter of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the first chapter of the exploration of the exploration of the first chapter of the exploration of the first chapter of the exploration of the exploration of the first chapter of the exploration of the exploration of the first chapter of the exploration of the exploration of the first chapter of the exploration of the exploration of the first chapter of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the exploration of the study of the Western home object model The basic requirements of this course are self-introduction
# 67.02 - 69.76	: Introduction to the environment
# 71.4 - 73.94	: Let's start with the first question
# 73.96 - 75.44	: Preference and learning effects
# 84.32 - 84.84	: This
# 90.0 - 93.0	: The title of our class is the exploration of the model of the west plus The concept of the model of the west plus
# 93.0 - 97.0	: I believe some of you may be very unfamiliar with it
# 97.0 - 99.0	: I may not have heard of it
# 99.0 - 105.28	: I also believe that there are some other friends who are very familiar with it
# 105.28 - 112.44	: But in fact, the word of the Western home object model can be said to be a long-standing name
# 112.44 - 117.16	: Familiar friends must have read a book called what
# 117.16 - 120.6	: It's called Exploring the Western Home Object Model
# 120.6 - 129.0	: There's a book called
# 131.0 - 134.0	: Deep exploration of the C++ object model Its English is inside
# 134.0 - 141.0	: The C++ Object Model
# 141.0 - 143.0	: It's a book like this
# 143.0 - 144.0	: So this book
# 144.0 - 146.66	: It can be said that in our C++ world It has a book like this So this book You could say that in our West home
# 146.66 - 149.5	: It has a very high degree of beauty
# 149.5 - 151.04	: Through this book
# 151.04 - 156.44	: This concept of the West home object model is slowly getting familiar with everyone
# 157.82 - 168.0	: So what is the main research of this West home object model What is he studying? He's mainly studying a lot of things that are not known to outsiders
# 168.0 - 170.68	: The inner work principle of the West plus plus object
# 173.5 - 178.94	: Research the inner work principle of the West plus plus object
# 180.34 - 184.68	: Some of the specific knowledge of the bottom line of the implementation mechanism
# 188.12 - 191.76	: So, yeah, you can understand it this way Our course of the subject model exploration of the West
# 191.76 - 193.06	: What is it
# 193.06 - 196.9	: It's about improving personal development and cultivation of the West
# 196.9 - 202.02	: Improve personal development and cultivation of the West
# 202.02 - 205.08	: Practice the internal work of the West C++ development and cultivation Practice
# 206.18 - 207.1	: C++
# 208.44 - 209.44	: C++ programming
# 211.76 - 214.76	: That's it
# 216.76 - 217.58	: That's it
# 221.48 - 226.24	: So what kind of effect
# 227.44 - 230.02	: Learning effect The teacher thinks there are three main aspects
# 232.54 - 233.5	: Three aspects
# 233.5 - 235.12	: Which three aspects
# 235.12 - 236.34	: The first one
# 236.34 - 239.28	: He can be to a great extent
# 239.28 - 241.14	: Expand your vision and thinking
# 244.42 - 251.82	: Let you know what you've done in the inside of the C++ surface code
# 251.82 - 252.78	: After learning
# 252.78 - 255.42	: You will feel your own level of ability
# 257.28 - 258.9	: After learning
# 258.9 - 259.62	: You will feel
# 261.48 - 262.32	: Your own level
# 263.7 - 268.76	: ability And the confidence in the technology of the developer of the West
# 268.76 - 271.6	: It's going to be a big deal
# 271.6 - 275.24	: That's how it feels
# 275.24 - 278.92	: It's a pre-emotional need for everyone to experience it
# 278.92 - 281.24	: And you're sure you can get that
# 281.24 - 282.32	: This is the first one
# 282.32 - 283.52	: Expand your eyes and thoughts
# 283.52 - 285.88	: The second is
# 288.16 - 289.76	: Answer the interview
# 293.48 - 294.3	: This one
# 294.32 - 300.04	: Many friends, especially those who participate in this job, have had the experience of this interview
# 300.04 - 301.6	: Find a job interview
# 301.6 - 302.86	: So when you're interviewing
# 302.86 - 305.64	: Occasionally you may encounter the following situation
# 305.64 - 306.66	: What's the situation
# 306.66 - 308.88	: For example, if you're a poor technical person
# 308.88 - 312.32	: Then the interviewer is the technical interviewer
# 312.32 - 314.0	: Not the one with human resources
# 314.0 - 316.0	: The technical interviewer
# 316.0 - 317.76	: He might despise you
# 317.76 - 319.32	: I feel like you're a poor technical person
# 319.32 - 321.76	: So if you're in the interview
# 321.76 - 322.56	: In some ways
# 322.56 - 325.22	: A little bit better than this interviewer
# 325.22 - 327.08	: Then he'll figure out how to pressure you
# 327.08 - 331.34	: He'll prove that he's better than you in some ways
# 331.34 - 334.82	: This is a kind of interviewer we occasionally see
# 334.82 - 336.68	: And there are some interviewers
# 336.68 - 342.74	: His performance is that if you show a very strong strength
# 342.74 - 344.62	: He will appreciate you very much
# 344.62 - 346.0	: And want to keep you in their hearts
# 346.0 - 348.0	: if you meet this kind of interviewer
# 348.0 - 350.0	: then you will have a big chance
# 350.0 - 352.0	: to find a job
# 352.0 - 354.0	: and success
# 354.0 - 356.0	: so in these interviewers
# 356.0 - 358.0	: who are kind and
# 358.0 - 360.0	: want to give you a hand
# 360.0 - 362.0	: no matter what kind of interviewer
# 362.0 - 364.0	: they will often ask
# 364.0 - 368.58	: some tricky questions
# 368.58 - 369.76	: This one
# 369.76 - 376.02	: And some interviewers will be proud of themselves for being able to ask such a tricky question
# 376.02 - 377.58	: In these tricky questions
# 377.58 - 384.48	: Often contains some of the knowledge we want to talk about in the model of the West plus plus object
# 384.48 - 386.96	: For example, he may ask you what to ask you
# 386.96 - 390.56	: Say a class that does not include any members
# 390.56 - 393.14	: How big is his size
# 393.14 - 394.94	: This is a question
# 394.94 - 397.4	: Sometimes this question
# 397.4 - 399.62	: For example, an empty class
# 399.62 - 401.68	: How big is the size of the empty class
# 403.44 - 406.0	: How big is the size of How big is sizeof? Or
# 406.0 - 408.0	: It may also ask you
# 408.0 - 412.0	: For example, some of the problems of the virtual function table
# 412.0 - 414.0	: May also ask
# 414.0 - 416.0	: Something like this
# 416.0 - 419.0	: So you can say that if you have not been in contact with this before
# 419.0 - 422.0	: This knowledge of the C++ object model
# 422.0 - 425.0	: You may not be able to answer this question
# 425.0 - 427.0	: if you can't answer it
# 427.0 - 431.0	: maybe the interviewer will judge you
# 431.0 - 436.0	: and you may lose the chance to work
# 436.0 - 438.0	: this is the second point
# 438.0 - 440.0	: we study to get the interview
# 440.0 - 442.0	: the third point
# 442.0 - 445.4	: is the word is the people's
# 445.4 - 449.84	: This word is a bit rough
# 449.84 - 451.84	: But this is not a rough reason
# 451.84 - 453.56	: Let's do the West home
# 453.56 - 455.32	: Develop this industry
# 455.32 - 456.8	: You're better than anyone else
# 456.8 - 458.18	: That's also a very proud thing
# 459.32 - 460.94	: But then again
# 460.94 - 463.76	: Whether you have three or five years of development experience
# 463.76 - 466.3	: Or have ten or eight years of development experience Or have ten or eight years of development experience
# 466.3 - 468.42	: Even longer development experience
# 468.42 - 470.44	: If you haven't studied this
# 470.44 - 475.16	: Some of the knowledge of the West's objects
# 475.16 - 479.14	: So it's possible that a very simple model problem for the West's objects
# 479.14 - 480.96	: You can't answer that
# 480.98 - 483.28	: It has nothing to do with your work age
# 483.28 - 486.0	: For example, the one we talked about above How big is the size of
# 486.0 - 488.0	: If you don't know this question, you won't be able to answer it
# 488.0 - 490.0	: In fact, a space
# 490.0 - 492.0	: It's a word
# 492.0 - 494.0	: It's a word
# 494.0 - 496.0	: Size of a space
# 496.0 - 498.0	: Equals to a word
# 498.0 - 500.0	: Then let's see
# 500.0 - 502.0	: Do you have friends who answer wrong
# 502.0 - 504.0	: Do you have friends who answer wrong
# 504.0 - 505.0	: So of course we will talk about why it is a word Why is it a word So let's see if any of our friends answered wrong
# 505.0 - 506.54	: Is there any friend who answered wrong
# 506.54 - 509.8	: So of course we'll talk about why he's a self-taught
# 511.32 - 512.92	: So as the saying goes
# 512.92 - 515.68	: The teacher thinks that as a life
# 515.68 - 517.28	: We are full of passion
# 517.28 - 520.3	: I want to challenge a little technical difficulty of the little friend
# 520.3 - 522.28	: Or as a hope to advance
# 522.28 - 524.1	: Grow up to be a master of the West
# 524.1 - 527.0	: Even the little friend of this master to be a master of the West Even the master level of the little friend
# 527.0 - 529.0	: So the West plus the object model
# 529.0 - 531.0	: The West plus the object model
# 531.0 - 534.0	: This course is so knowledge
# 534.0 - 538.0	: It's all very rare and very worth learning
# 538.0 - 540.0	: This is the first one the teacher talked about
# 540.0 - 543.0	: Preview and learning effect
# 543.0 - 546.48	: Okay, so let's take a look at the second question
# 546.48 - 549.76	: Here's the second question
# 549.76 - 553.08	: What is the research of the model of the West's object
# 553.08 - 568.28	: So what is the research ofiajia object model?
# 568.28 - 571.6	: That is to say, which knowledge is being studied
# 571.6 - 577.2	: Everyone knows that Xijiajia is a language that supports the programming design of the face-to-face object
# 577.2 - 578.54	: So this kind of support
# 578.54 - 582.06	: It's definitely going to take the underlying system
# 582.06 - 583.84	: But all kinds of things
# 584.88 - 587.2	: So, ah X the C++ editor
# 587.2 - 589.54	: Behind us programmers
# 589.54 - 591.38	: It's actually done a lot of things
# 592.38 - 594.52	: For example, when we generate objects
# 594.52 - 596.54	: The structure function of the call type
# 596.54 - 598.14	: When you release the object
# 598.14 - 599.52	: The function of the call type
# 600.82 - 604.18	: When we don't define our own copy structure function
# 604.18 - 607.84	: The editor will also help us to merge a copy structure function
# 607.84 - 608.56	: And so on
# 608.56 - 610.8	: This series of actions behind
# 610.8 - 614.0	: So what we're doing in this class is
# 614.0 - 616.08	: The bottom layers of the system
# 616.08 - 618.96	: How to achieve all kinds of things
# 618.96 - 621.96	: research
# 621.96 - 630.4	: The bottom layers of the system inside the system
# 632.4 - 635.68	: What are the prominent features of the face-to-face design language
# 635.7 - 637.76	: You know, it's a inheritance
# 637.76 - 638.48	: It works with a lot of times
# 642.38 - 643.88	: These two features
# 643.88 - 647.04	: So what are the specific details of these two features
# 647.04 - 649.12	: How did the expense come about
# 649.12 - 650.16	: And so on
# 650.16 - 652.72	: That's all we're talking about
# 653.98 - 657.64	: So since we're here to explore the object model
# 658.6 - 661.52	: We're going to go around more and more
# 661.52 - 663.22	: The object to discuss the problem
# 664.42 - 665.24	: More is Discuss the problem around the type of object More
# 667.04 - 671.16	: Discuss the type of object
# 674.7 - 679.62	: According to the normal learning of the learning journey developed by learning the language
# 679.62 - 680.4	: It can be said that
# 681.36 - 683.64	: You can not learn
# 683.64 - 686.36	: These are the knowledge of the type of object of the west plus You can not learn these knowledge of the C++ object model
# 686.36 - 687.14	: You can not learn
# 688.28 - 693.86	: Or you can't learn these knowledge
# 694.84 - 697.46	: So let's start this course
# 697.46 - 698.78	: To learn this knowledge
# 699.86 - 701.56	: C++ object model
# 701.58 - 703.0	: His knowledge
# 703.02 - 704.0	: Overall
# 708.76 - 715.52	: The information on the subject is not too much in the whole picture But these knowledge can improve our overall quality in the form of nothing
# 715.52 - 717.76	: It plays a key role
# 717.76 - 722.8	: So this learning or not learning depends entirely on your own thoughts and decisions
# 724.24 - 729.78	: This is the teacher who defined this class as a master advanced
# 729.78 - 732.9	: One of the main reasons for this course
# 732.9 - 738.08	: If you just use this Xijiajia to deal with the daily development of the normal
# 738.08 - 740.88	: You can not learn this Xijiajia object model
# 740.88 - 742.44	: These knowledge
# 742.44 - 744.36	: But if you want to grow into this
# 744.36 - 747.5	: Everyone is more recognized as a master of the X plus plus
# 747.5 - 749.32	: Even if it's a master
# 749.34 - 751.7	: Then this class is a must
# 752.78 - 754.34	: Or in other words
# 754.34 - 759.52	: This class is actually mainly aimed at the X plus plus programming experience
# 759.54 - 761.0	: More rich
# 761.0 - 764.12	: And I hope to further improve my knowledge
# 764.12 - 769.0	: I hope to further understand the bottom of the system is doing
# 774.0 - 778.0	: this course is for
# 781.0 - 784.0	: Xijiajia programming experience
# 784.0 - 789.0	: and I hope you further improve his knowledge
# 789.0 - 796.0	: Hope to further understand what the system is doing
# 799.0 - 802.0	: Old driver should say this
# 802.0 - 805.24	: This wants to further improve its development
# 805.24 - 808.0	: The ability to drive like this
# 808.0 - 809.38	: This is what we talked about
# 809.4 - 813.56	: The second question is what the West plus plus model is studying
# 813.56 - 815.72	: He's just around this bunch of people to study
# 815.72 - 816.56	: Ah, let's talk about it
# 818.34 - 819.94	: The second question we're done
# 819.96 - 822.38	: Let's talk about the third question
# 822.38 - 824.12	: The basic requirements of this course
# 822.4 - 824.14	: Let's talk about the third question The basic requirements for learning this course
# 829.46 - 837.14	: The class is not required to have too much knowledge of the new standard of the 14th century
# 837.14 - 837.7	: But?
# 837.7 - 839.56	: Everyone is for the traditional Xijiajia
# 839.56 - 842.88	: That's the version of Xijiajia 98
# 842.88 - 845.22	: The development of the local language is relatively familiar
# 845.22 - 848.0	: For example, this is what we call this
# 848.0 - 848.82	: Tired of this concept
# 850.32 - 865.78	: Objects, A relatively familiar understanding or understanding
# 865.8 - 871.48	: The teacher hopes that the friends who study this course will at least use one or two years of Xi Jiajia
# 876.56 - 882.44	: And then when you do a more objective or regular assessment of your own abilities
# 882.44 - 885.76	: Think of yourself as being able to achieve a kind of ultimate application level
# 889.7 - 893.82	: What should everyone experience as a level of ultimate application
# 893.82 - 896.8	: If you think you're not good enough for your knowledge
# 896.8 - 899.74	: The teacher recommended this to you
# 899.74 - 902.02	: My other course is
# 904.58 - 905.24	: Xi Jiajia
# 906.3 - 907.02	: From the entrance
# 909.22 - 910.0	: To the elite
# 912.18 - 915.0	: Xi Jiajia 11 14 17 ah
# 915.0 - 919.5	: This class is not only about the traditional ah Xi Jiajia bar
# 919.5 - 920.96	: I also talked about the new standard of Xi Jiajia
# 920.98 - 922.26	: 11 14 17
# 922.26 - 925.82	: This is a very good course
# 925.82 - 927.86	: This course is very close
# 927.86 - 932.3	: It's very suitable for beginners
# 932.3 - 933.38	: And after you've learned it
# 933.38 - 937.82	: You can reach a high-level development level in the West
# 937.82 - 941.8	: It's very suitable for this to play this development foundation
# 943.52 - 966.0	: So this course has a very good reputation in this school Play this I'm familiar with it The fourth question is simple I'll introduce myself
# 972.0 - 973.0	: ah
# 973.0 - 975.0	: Because the teacher just had his birthday
# 975.0 - 977.0	: So this can be said to be up to now
# 977.0 - 979.0	: The teacher has been doing it for 24 years
# 979.0 - 981.0	: 24 years of Xi Jiajia
# 981.0 - 983.0	: Old driver
# 983.0 - 987.56	: The main field of the teacher's work is telecommunications
# 987.56 - 988.16	: Telecommunications field
# 989.36 - 990.86	: This network security field
# 993.44 - 995.12	: And the network game field
# 996.94 - 999.38	: There may be an adventure road on the Internet
# 1000.52 - 1006.5	: This is a global network game This is the world's first online game
# 1006.5 - 1009.0	: This is developed by the teacher
# 1009.0 - 1012.0	: The main thing is that the teacher is developing his own game
# 1012.0 - 1017.0	: So the teacher has been through a lot of projects
# 1017.0 - 1019.0	: Some of the projects are very large
# 1019.0 - 1021.0	: It's done by the teacher
# 1021.0 - 1024.0	: It can be said that a person usually relies on hundreds of thousands of codes
# 1024.0 - 1026.0	: It's a very common thing to do I'm not the same as many other teachers I have a talent for lectures
# 1026.0 - 1028.0	: This is inherited
# 1028.0 - 1030.0	: Many of our family members are teachers
# 1030.0 - 1033.0	: So the characteristics of my lectures are
# 1033.0 - 1035.0	: This is more accurate
# 1035.0 - 1037.0	: The characteristics of my lectures are accurate
# 1037.0 - 1040.0	: This is less than a hundred
# 1040.0 - 1042.0	: I'm not saying that I'm not good at it
# 1042.0 - 1044.0	: I'm not saying that I'm not good at it
# 1044.0 - 1046.0	: I'm not saying that I'm not good at it I'm not saying that I'm not good at it So, the characteristics of my lecture is More accurate The characteristics of my lecture is accurate
# 1046.0 - 1052.0	: More than less
# 1052.0 - 1056.0	: More than less
# 1056.0 - 1060.0	: What does it mean by more than less?
# 1060.0 - 1062.0	: I'm just telling you what you need to know
# 1062.0 - 1065.88	: I won't go too deep In case I make you confused you what you need to know I won't go too deep
# 1065.88 - 1069.68	: In case I make you confused about what you already know
# 1069.68 - 1072.78	: In fact, I found it really difficult to be a qualified teacher
# 1072.78 - 1075.98	: Most of the teachers are very knowledgeable
# 1075.98 - 1077.4	: But if he says it
# 1077.4 - 1079.34	: You can't understand it
# 1079.34 - 1081.24	: The more complex the knowledge point
# 1081.24 - 1082.94	: This point is more obvious
# 1082.94 - 1085.7	: The more he can tell you that you don't understand
# 1087.24 - 1089.9	: So there's a saying called what There's no comparison, there's no harm
# 1089.9 - 1093.82	: I believe that friends who have heard other teachers talk about it will not be self-conscious
# 1093.82 - 1094.3	: Is it
# 1094.3 - 1097.1	: Take this other teacher to compare with me
# 1098.12 - 1098.54	: This one
# 1098.54 - 1100.4	: Let's see who can tell us
# 1100.4 - 1101.78	: Who didn't tell us
# 1101.78 - 1104.12	: But this teacher has confidence
# 1104.12 - 1106.12	: Teach you well
# 1106.12 - 1114.52	: The teacher also believes that we will give the teacher a more objective and fair and high quality evaluation
# 1114.52 - 1116.14	: High quality evaluation
# 1116.14 - 1118.8	: This is the teacher's simple self-introduction
# 1118.8 - 1132.56	: Let's take a look at the explanation I have two main courses in this course
# 1132.56 - 1136.24	: The first is the book I mentioned before
# 1136.24 - 1140.26	: Exploring the model of the West
# 1142.72 - 1151.0	: Wait a minute
# 1153.0 - 1160.0	: I'll be honest with you This book is a very famous book
# 1160.0 - 1166.0	: Its author is Leap This is the author
# 1166.0 - 1187.04	: This author is involved in designing the world's first set of Xijiajia Many readers have read this book It may be on Dangdang or some other book sites
# 1187.04 - 1189.64	: There may be thousands of books
# 1189.64 - 1191.1	: There are a lot of books
# 1191.1 - 1195.06	: Many readers like this book very much
# 1195.06 - 1198.06	: But it also generally reflects some problems
# 1198.06 - 1201.18	: For example, the content is gray when reading
# 1201.18 - 1204.68	: There may be some problems when translating
# 1204.68 - 1206.36	: The teacher thinks
# 1206.36 - 1207.74	: No matter what
# 1207.74 - 1209.98	: This is not a joke
# 1210.0 - 1210.94	: The teacher?
# 1210.96 - 1213.1	: I think this book is still great
# 1213.12 - 1214.34	: Great!
# 1214.34 - 1216.76	: So when the teacher talks about you
# 1216.76 - 1218.5	: Will refer to this book
# 1218.52 - 1220.36	: What is the principle of reference
# 1220.38 - 1223.24	: Just to introduce you to the teacher
# 1223.24 - 1226.8	: I think it's useful that you need to know
# 1226.8 - 1232.8	: to prove that the description in the book is true
# 1232.8 - 1235.8	: What are the principles that the teacher is talking about?
# 1235.8 - 1247.12	: The principles that the teacher thinks are useful and useful It's useful to everyone And then? What we need to know
# 1247.12 - 1253.34	: Can be proved by the demonstration of the law
# 1253.34 - 1254.64	: You can say a knowledge theory
# 1254.64 - 1256.38	: But you can't prove it
# 1256.38 - 1258.38	: So you don't know if this theory is right or wrong
# 1258.38 - 1260.68	: That's what's necessary
# 1260.68 - 1262.28	: It's small, isn't it
# 1262.28 - 1264.08	: Prove the evidence of the demonstration
# 1264.08 - 1265.0	: Prove it is true
# 1267.68 - 1268.28	: Such content
# 1271.16 - 1272.08	: On the contrary
# 1272.1 - 1274.36	: Some of the two can be known
# 1274.38 - 1275.5	: Do not know
# 1275.52 - 1277.76	: Or hard to prove the truth
# 1277.76 - 1279.68	: Hard to prove the truth
# 1279.68 - 1282.16	: We may not introduce it
# 1282.18 - 1282.76	: This one
# 1282.78 - 1285.1	: If a friend thinks
# 1285.1 - 1285.96	: I bought this book
# 1285.98 - 1287.56	: You may not understand
# 1287.56 - 1289.66	: Or you spent ten minutes
# 1289.66 - 1292.62	: You got six out of ten
# 1292.62 - 1294.9	: So the teacher
# 1294.9 - 1296.68	: We talked about the west home to the object
# 1296.68 - 1297.3	: No exploration
# 1297.32 - 1298.54	: This class
# 1298.54 - 1303.06	: So the meaning of existence is that the teacher can only spend two minutes
# 1303.08 - 1307.18	: You can understand the eight to ten points of it
# 1307.18 - 1307.98	: At the same time
# 1307.98 - 1312.48	: Let you get an extra teacher for the Western home
# 1312.48 - 1314.3	: Some of the concepts of the object model
# 1314.3 - 1318.32	: Some new experiences and some new points of knowledge
# 1319.76 - 1321.42	: So this is the first point
# 1321.42 - 1331.22	: The second explanation is that the teacher will refer to various materials on the Internet
# 1331.22 - 1332.84	: All kinds of information about the model of the West
# 1332.84 - 1337.74	: There are actually a lot of friends on the Internet
# 1337.74 - 1340.72	: And a lot of friends who love the model of the West
# 1340.72 - 1346.02	: They did all kinds of learning and research
# 1346.02 - 1348.42	: Some people even studied very deeply
# 1348.42 - 1352.06	: So the teacher of course can't let go of such a knowledge point
# 1352.06 - 1355.78	: Combine all kinds of these relevant information online
# 1355.78 - 1358.12	: By sorting and digesting
# 1358.12 - 1362.46	: This teacher will sort out the digestion
# 1362.46 - 1369.32	: And then the most ex to share this thing with you
# 1369.32 - 1370.26	: In this course
# 1370.26 - 1378.3	: Share with you the purpose of only one is to let you use the least time to master the most useful knowledge
# 1378.3 - 1379.68	: Because for everyone
# 1379.68 - 1380.96	: What is the most precious
# 1380.98 - 1383.28	: The most precious thing is actually time
# 1383.28 - 1384.32	: Especially when you go to work
# 1384.34 - 1386.18	: You will be friends in the future Maybe you can't feel it so Especially when you're working You'll be friends in the future
# 1386.18 - 1388.7	: Maybe you can't feel it so well when you're in college
# 1388.7 - 1389.76	: Friends who participate in work
# 1389.76 - 1391.52	: Especially those who work overtime every day
# 1391.52 - 1393.0	: Sometimes a week to six days
# 1393.0 - 1394.58	: Friends who work overtime until 11 o'clock every day
# 1394.58 - 1395.54	: You know
# 1395.54 - 1398.3	: Time is too precious for you
# 1398.3 - 1402.48	: Maybe you're too busy to learn and improve your ability
# 1402.48 - 1404.32	: I'm busy with my company every day
# 1404.32 - 1406.0	: Just busy to this extent Learn and improve your ability I'm busy with the company every day That's how busy I am
# 1406.0 - 1408.0	: The teacher is going to be strong
# 1408.0 - 1410.0	: Let's talk about this
# 1410.0 - 1412.0	: When the Xijiajia对象模型探索课程
# 1412.0 - 1414.0	: Will include a lot of new things
# 1414.0 - 1417.0	: Including the teacher's own thinking
# 1417.0 - 1418.0	: Experience
# 1418.0 - 1420.0	: And the teacher will
# 1420.0 - 1422.0	: The main problem
# 1422.0 - 1424.0	: To personally demonstrate and demonstrate
# 1424.0 - 1426.32	: We're not just talking We're going a few questions to demonstrate and demonstrate We're not just talking about it
# 1426.32 - 1431.04	: We're going to write code to demonstrate and demonstrate these theories
# 1431.04 - 1435.36	: So the teacher's class I believe you won't think it's bad
# 1435.36 - 1436.32	: At the same time
# 1436.32 - 1439.96	: Through all kinds of teacher's writing
# 1439.96 - 1440.8	: This one
# 1440.8 - 1465.74	: You can see it more closely This one Everyone can take a question is to explain the environment
# 1472.78 - 1474.74	: The teacher taught this course
# 1474.74 - 1476.68	: I just said that we can't avoid doing it
# 1476.68 - 1479.88	: The teacher will use the Windows platform when he shows
# 1482.92 - 1483.5	: Mainly
# 1484.68 - 1485.2	: Mainly To show this mainly mainly
# 1485.2 - 1488.2	: to show
# 1488.2 - 1490.0	: but
# 1490.0 - 1492.1	: considering the complexity of our knowledge
# 1492.1 - 1495.6	: when this windows
# 1495.6 - 1497.6	: and linux
# 1497.6 - 1499.4	: these two main platforms
# 1499.4 - 1501.4	: when the difference is relatively obvious
# 1501.4 - 1513.76	: teachers sometimes will do the demonstrations on the Linux platform
# 1516.14 - 1517.44	: Do demonstrations This one
# 1517.44 - 1518.36	: This specific demonstration
# 1518.36 - 1519.68	: Let's analyze the specific situation
# 1521.48 - 1523.0	: This is the main one
# 1523.0 - 1524.6	: The other one is the main demonstration
# 1524.6 - 1525.46	: That's what it means one on the Windows platform The other one is just a copy of the demo That's what it means
# 1527.02 - 1528.34	: So on the Windows platform
# 1528.34 - 1531.22	: The main environment that the teacher shows is the Vs 2017
# 1531.22 - 1535.36	: This is the C++ development environment on the Windows platform
# 1535.36 - 1537.82	: In fact, the Vs 2017 is a high-level development environment
# 1537.82 - 1539.64	: It can develop a lot of this
# 1539.64 - 1541.4	: The code written in the language
# 1541.4 - 1542.56	: That's what we're talking about
# 1542.56 - 1545.36	: It's mainly written in the development environment
# 1545.36 - 1546.84	: This environment is very good
# 1546.84 - 1548.68	: It's very convenient to adjust
# 1548.68 - 1550.08	: It's convenient to adjust
# 1550.08 - 1551.84	: It means that when I explain to you
# 1551.84 - 1553.96	: It's very convenient for us to show it
# 1553.96 - 1555.8	: It's very easy for everyone
# 1555.8 - 1559.08	: Can understand the content of the teacher's demonstration
# 1559.08 - 1560.72	: This is the vr3 issue
# 1560.72 - 1561.88	: Everyone pay attention to this
# 1561.88 - 1567.0	: It has a free community version The2017 version is free
# 1567.0 - 1573.0	: community version
# 1573.0 - 1578.0	: you can install VS2017 via the internet
# 1578.0 - 1583.0	: because you need to download the whole thing via the internet
# 1583.0 - 1585.78	: it takes about two to four hours
# 1585.78 - 1587.3	: And the space to suck
# 1590.02 - 1591.52	: It is recommended that more than 20 G
# 1593.44 - 1597.12	: This teacher is not going to take you to install this VsR
# 1597.12 - 1597.88	: This issue
# 1597.88 - 1599.08	: Everyone is self-explanatory
# 1599.08 - 1600.7	: Search this how to install VsR
# 1600.7 - 1602.38	: When you install it
# 1602.38 - 1604.8	: Pay attention to some options
# 1604.8 - 1605.6	: Install options
# 1608.38 - 1611.4	: There are some Xijiajia development related
# 1613.5 - 1616.4	: We'll choose the general development options
# 1616.4 - 1618.54	: It's all with the word Xijiajia
# 1618.54 - 1621.0	: If it's not related to Xijiajia development options
# 1621.0 - 1622.62	: Don't hook up
# 1622.62 - 1624.78	: This is not related to Xijiajia
# 1629.6 - 1632.76	: Don't hook up If you really can't confirm it, contact your teacher through QQ or other ways
# 1632.76 - 1639.08	: Contact your teacher or ask some people who have installed VS2017 on the Internet
# 1639.08 - 1641.12	: See what they have chosen
# 1641.12 - 1642.68	: Don't install it all
# 1642.68 - 1646.04	: If you install it all, you may need a hard drive space of 180GB
# 1646.04 - 1649.0	: and it may take several tens of GB on the hard drive
# 1649.0 - 1652.0	: that's a bit of a hassle
# 1652.0 - 1655.0	: you may have to install a lot of systems
# 1655.0 - 1658.0	: so this is the option related to the development of the C++
# 1658.0 - 1661.0	: anyway, if you install less, it's okay
# 1661.0 - 1664.0	: if you install more, of course you can download more
# 1664.0 - 1670.08	: if you install less, you can't do without it You can download it if you have a lot of it You can use the installation program to add and install it if you have a lot of it
# 1670.08 - 1671.76	: Don't worry about it
# 1671.76 - 1672.24	: Of course
# 1672.24 - 1674.64	: Some of you may not be a computer student
# 1674.64 - 1677.76	: Maybe there's this VS2010 VS2012
# 1677.76 - 1679.28	: Because this class is more traditional
# 1679.28 - 1682.08	: We don't need to use too new c++ standards
# 1682.08 - 1683.76	: So VS2010
# 1683.76 - 1686.0	: 1022012 Even VS205 is possible You can use it in the next video So you can use it in the next video So you can use it in the next video
# 1686.0 - 1688.0	: So you can use it in the next video
# 1688.0 - 1690.0	: So you can use it in the next video
# 1690.0 - 1692.0	: So you can use it in the next video
# 1692.0 - 1694.0	: So you can use it in the next video
# 1694.0 - 1696.0	: So you can use it in the next video
# 1696.0 - 1698.0	: So you can use it in the next video
# 1698.0 - 1700.0	: So you can use it in the next video
# 1700.0 - 1702.0	: So you can use it in the next video
# 1702.0 - 1704.0	: So you can use it in the next video
# 1704.0 - 1706.0	: So you can use it in the next video So you can use it in the next video I installed an Ubuntu Linux How to play Ubuntu? Let's just use Chinese
# 1706.0 - 1709.0	: I haven't remembered how to play Ubuntu since I've been using it for a long time
# 1709.0 - 1711.0	: Ubuntu Linux
# 1711.0 - 1714.0	: I installed a virtual machine on this computer
# 1714.0 - 1716.0	: Ubuntu Linux is installed in the virtual machine
# 1716.0 - 1718.0	: Then we will be in this operating system
# 1718.0 - 1723.0	: Show the c++ of our Linux
# 1723.0 - 1726.06	: For programming and operation The teacher is in this picture
# 1726.06 - 1729.66	: I put a GCC and this Gjiajia on it
# 1729.66 - 1731.58	: Let's use it because we are Xijiajia program
# 1731.58 - 1733.72	: Let's use the translation of Gjiajia to translate it
# 1733.72 - 1734.46	: Right?
# 1734.46 - 1737.6	: If you haven't played this Linux
# 1737.6 - 1739.14	: This is the classmate
# 1739.14 - 1743.3	: This teacher also does not recommend you to build this development environment
# 1743.3 - 1744.48	: Because I haven't played this one
# 1744.48 - 1747.2	: This one is the one who runs the operating system
# 1747.2 - 1748.52	: He's building this development environment
# 1748.52 - 1750.32	: It's still a little bit complicated
# 1750.32 - 1752.96	: You can just watch the teacher show you the results
# 1752.96 - 1754.88	: It can also achieve this learning effect
# 1754.88 - 1755.24	: Of course
# 1755.24 - 1757.82	: If you can build this one yourself
# 1757.82 - 1759.2	: This one is the one that's going to develop the environment
# 1759.2 - 1759.86	: That's better
# 1759.86 - 1760.94	: Right?
# 1760.94 - 1762.0	: This one is here
# 1762.0 - 1763.7	: The teacher is not going to take everyone to build this one
# 1763.7 - 1767.0	: Linus developed the West and West development environment Because the focus of our class is not I'm not going to show you how to build a Linux developer environment
# 1767.0 - 1773.0	: because this lesson is not about Linux developer
# 1773.0 - 1775.0	: it's not a lesson like this
# 1775.0 - 1785.24	: I'm just assuming that you have successfully installed the Vs's this integrated development environment
# 1785.24 - 1787.2	: For example, the teacher is on this computer
# 1787.2 - 1789.36	: It's already installed
# 1789.36 - 1793.38	: This is the Vs2017
# 1793.38 - 1794.6	: What about now
# 1794.62 - 1797.78	: Let's set up this development environment
# 1797.8 - 1798.6	: Let's set it up
# 1798.6 - 1802.24	: Let's set it up to fit our development environment
# 1802.24 - 1803.58	: Let's see how to set it up
# 1803.58 - 1804.2	: After installation
# 1804.22 - 1807.2	: Let's double click on this desktop vs2017
# 1807.2 - 1808.4	: Double click vs2017
# 1809.5 - 1814.7	: And then we follow the teacher to do the following operations
# 1814.7 - 1815.8	: How to operate
# 1815.8 - 1817.6	: Look at the tool
# 1817.6 - 1819.5	: There's a tool on the menu, isn't it
# 1819.5 - 1821.6	: Insert and exit settings
# 1821.6 - 1824.8	: Select and then pop up a question mark
# 1824.8 - 1846.36	: Let's look at the bottom There are all the settings and then my current settings And then click next
# 1848.78 - 1851.4	: And then there are a lot of development languages
# 1851.4 - 1853.16	: JavaScript, VB, etc.
# 1853.16 - 1855.8	: Let's choose the virtual C++ inside
# 1855.8 - 1857.68	: If you can't see this option
# 1857.68 - 1860.84	: It's very likely that you didn't install it when you installed it
# 1860.84 - 1862.68	: At this time you have to re-install the program
# 1862.68 - 1865.76	: You have to install this relevant Xijiajia option
# 1865.76 - 1867.88	: Okay, let's choose this VXJ
# 1868.38 - 1870.68	: This one and then select complete
# 1873.12 - 1874.4	: That's how the system is going to be
# 1874.4 - 1876.26	: Maybe you have to configure it for a few seconds
# 1876.26 - 1877.28	: After a few seconds
# 1877.28 - 1882.44	: He just recorded some configuration information into some configuration files
# 1882.44 - 1886.84	: Now let's go to this VS 2017
# 1886.84 - 1890.2	: Let's create a project in this environment
# 1890.2 - 1891.76	: Why create a project
# 1891.76 - 1892.8	: Because of this
# 1892.8 - 1896.08	: Friends familiar with this programming environment know this project
# 1896.08 - 1897.96	: It's our VS 2017
# 1897.96 - 1899.84	: The basic unit of management
# 1899.84 - 1901.0	: The basic unit of management
# 1901.0 - 1903.04	: So let's create a project
# 1903.04 - 1905.0	: Let's take a look at how to create The teacher is taking you to create a project This is because of the creation start a project Let's take a look at how to create
# 1905.0 - 1906.96	: The teacher is taking you to start a project
# 1906.96 - 1908.82	: Because of the project
# 1908.82 - 1910.8	: It's easy for us to show you the following courses
# 1912.0 - 1913.82	: What file to choose
# 1913.82 - 1915.78	: Is it a new project
# 1915.78 - 1917.1	: This project is a project
# 1917.1 - 1917.84	: The project is a project
# 1917.84 - 1919.26	: Let's first understand this first
# 1919.26 - 1922.32	: Everyone has a good new project
# 1925.1 - 1927.5	: Then wait a few seconds
# 1927.5 - 1928.18	: Left and right
# 1928.18 - 1928.64	: On the left
# 1928.64 - 1929.22	: Let's see
# 1929.22 - 1931.04	: There's a Vito's home
# 1931.04 - 1932.54	: If there's no Vito's home
# 1932.54 - 1933.8	: Let's see if there's any other language
# 1933.8 - 1935.26	: If there's no other language
# 1935.26 - 1936.66	: That means you're not in power
# 1936.66 - 1938.48	: You have to consider this
# 1938.48 - 1942.34	: Add some installation options
# 1942.34 - 1943.7	: Why is the price on the right side
# 1943.7 - 1944.5	: What do we choose
# 1944.5 - 1948.16	: Choose a Windows control
# 1948.16 - 1950.08	: He can use the program
# 1950.08 - 1951.92	: And then here's the name
# 1951.92 - 1953.12	: What should we name it
# 1953.12 - 1954.46	: Let's start with a project
# 1956.26 - 1958.9	: Here's a hundred
# 1958.9 - 1960.74	: And then what about this position
# 1960.74 - 1961.6	: What do we give
# 1961.6 - 1963.28	: The position we give a case
# 1963.28 - 1965.1	: Let's give a self-established model
# 1965.1 - 1966.3	: Give a case position
# 1966.3 - 1967.22	: And then the solution
# 1967.24 - 1968.82	: Pay attention to the solution
# 1968.82 - 1971.12	: We can give a solution
# 1973.38 - 1975.06	: One hundred can do this
# 1975.06 - 1978.12	: In fact, a solution is this
# 1979.08 - 1980.44	: This is the management unit of the VXU
# 1980.44 - 1982.92	: A solution can correspond to this
# 1982.92 - 1984.84	: We're not creating a project now
# 1984.84 - 1987.44	: A solution can correspond to a hot project It can create a project In a solution, we can create a project
# 1987.44 - 1989.04	: It's a comprehensive relationship
# 1989.04 - 1991.04	: The solution is bigger, the project is smaller
# 1991.04 - 1995.36	: Then a project will generate a executable file
# 1995.36 - 1999.2	: Then this project contains a lot of original code files
# 1999.2 - 2001.68	: In the end, a executable file can be generated
# 2001.68 - 2002.88	: That's it
# 2002.88 - 2004.96	: This is called a project
# 2004.96 - 2005.46	: Okay, let's click on OK We can generate a feasible document That's it This is called a project
# 2006.26 - 2008.38	: Let's click OK
# 2009.96 - 2011.3	: Click OK We're going to wait a few seconds here
# 2011.32 - 2014.54	: The system will automatically create a project for us
# 2014.56 - 2015.38	: Create a project
# 2015.4 - 2017.52	: That's what we call this project
# 2017.52 - 2017.94	: Project
# 2019.18 - 2019.94	: Okay, wait a minute
# 2019.94 - 2020.42	: Wait a minute
# 2024.12 - 2025.28	: It's a little bit slow
# 2025.28 - 2025.82	: A little bit slow
# 2033.02 - 2034.28	: Waited a few seconds
# 2034.28 - 2035.78	: This system came out
# 2035.78 - 2037.52	: Let's take a look at this one
# 2037.52 - 2038.96	: This is our solution
# 2038.96 - 2040.58	: This is the project below
# 2040.58 - 2041.3	: That is, the project
# 2041.3 - 2042.62	: You see a solution
# 2042.62 - 2043.88	: It now includes a project
# 2043.88 - 2045.72	: In fact, it can include a lot of projects
# 2045.74 - 2048.42	: This solution can also be a new project
# 2048.44 - 2050.46	: Let's just not study it specifically
# 2050.48 - 2051.16	: I'm not going to study it
# 2051.16 - 2054.04	: Now this project that was created
# 2054.04 - 2057.52	: We see this project name is the project we input 100
# 2057.52 - 2059.86	: This project is also called this project
# 2059.86 - 2064.7	: So this is under this solution 100 solution
# 2064.7 - 2069.2	: So this Now let's see
# 2069.2 - 2071.8	: Under the project100 project
# 2071.8 - 2073.7	: Let's look at the original file
# 2073.7 - 2076.3	: There is a main file called project100
# 2076.3 - 2078.7	: Double dot is the original code
# 2078.7 - 2079.7	: You see
# 2079.7 - 2082.5	: This vr317 automatically creates for us
# 2082.5 - 2085.64	: This project100.cpp for us
# 2085.64 - 2087.94	: The main 7++ original file
# 2087.94 - 2090.2	: And then there's a code that's generated
# 2090.2 - 2091.82	: After generating a code
# 2091.82 - 2093.46	: This code in here
# 2093.46 - 2095.68	: It's very simple
# 2095.68 - 2098.0	: This one, we can get rid of these
# 2098.0 - 2099.56	: These are useless
# 2099.56 - 2101.3	: And then here we'll edit it
# 2101.3 - 2103.16	: Create a solution program
# 2103.16 - 2104.56	: This menu to edit
# 2105.0 - 2108.0	: Because these codes are automatically generated
# 2108.0 - 2111.0	: It should be returned here
# 2111.0 - 2114.0	: Let's add it here
# 2114.0 - 2118.0	: Let's add a return 0
# 2118.0 - 2121.0	: 0 or return 1
# 2121.0 - 2123.0	: No matter if it's return 0 or return 1
# 2123.0 - 2126.0	: Because the main function is the execution entrance of the entire program There is an int return 1 no matter return 0 or return 1 because the main function is the execution entrance of the entire program
# 2126.0 - 2128.0	: there will be an int return 1
# 2128.0 - 2130.0	: return 1
# 2130.0 - 2132.0	: ok, let's make it again
# 2134.0 - 2136.0	: are you familiar with the operation of this VAS?
# 2136.0 - 2138.0	: ctrl f5
# 2138.0 - 2140.0	: this shortcut key ctrl f5
# 2140.0 - 2142.0	: is the executable program
# 2142.0 - 2144.0	: you can see it shows a hello world
# 2144.0 - 2146.72	: if you can't execute the control f5
# 2146.72 - 2148.4	: If the shortcut is not easy to use
# 2148.4 - 2149.38	: So what can we do
# 2149.4 - 2150.06	: What's the production
# 2150.06 - 2150.62	: There's one here
# 2150.62 - 2151.34	: Pay attention to the production
# 2151.34 - 2152.08	: There's one here
# 2152.72 - 2153.2	: This one
# 2154.68 - 2155.12	: Not here
# 2155.12 - 2156.38	: Here is the bridge
# 2156.38 - 2156.92	: There's one here
# 2156.92 - 2158.0	: Start execution
# 2158.0 - 2159.2	: Control F5 is the same
# 2159.2 - 2161.54	: You can execute this program
# 2161.54 - 2163.4	: This effect is the same as control F5
# 2163.4 - 2164.12	: After execution
# 2164.12 - 2166.1	: You see a black window
# 2166.1 - 2168.24	: this black window shows hello world
# 2168.24 - 2170.82	: this means the whole program is executed successfully
# 2170.82 - 2172.66	: it's executed successfully
# 2172.66 - 2175.4	: because there is only one code in the code
# 2175.4 - 2178.16	: and only one line shows hello world
# 2178.16 - 2180.86	: the rest of the lines are not useful
# 2180.86 - 2183.84	: so this program is successfully edited
# 2183.84 - 2186.0	: this has achieved the performance we want So this is the process now The translation is successful This is the effect of our demonstration
# 2186.0 - 2188.0	: Everyone see the voice
# 2188.0 - 2190.0	: See if the translation is successful
# 2190.0 - 2192.0	: When you wait for the solution to be solved
# 2192.0 - 2194.0	: He will remind you to claim success
# 2194.0 - 2196.0	: That means our project
# 2196.0 - 2198.0	: Claim success
# 2198.0 - 2200.0	: That's it
# 2200.0 - 2202.0	: Let's build up the whole project
# 2202.0 - 2204.0	: Next class
# 2204.0 - 2205.96	: Or when we want to show it later
# 2205.98 - 2210.02	: Let's write code here to show it
# 2210.02 - 2211.82	: Okay, then from the next class
# 2211.82 - 2216.48	: Let's really get into this West home object model
# 2216.48 - 2220.14	: This course of this formal explanation
# 2220.14 - 2223.74	: The teacher recommends that everyone at least put this VS this
# 2223.74 - 2224.84	: This development environment
# 2224.84 - 2226.48	: We need to install it This must be the content we are talking about I suggest you at least install the VS development environment
# 2226.48 - 2233.84	: After all, if you can listen to the content we talk about in person
# 2233.84 - 2237.56	: If you can do it yourself and demonstrate it
# 2237.56 - 2240.92	: The learning effect may be much better
# 2240.92 - 2243.48	: I suggest you can practice it yourself
# 2243.48 - 2246.36	: Listen to the lesson in class and practice it yourself
# 2246.36 - 2248.12	: That's all for this class
# 2248.12 - 2249.12	: Thank you for watching
# 2249.12 - 2250.56	: I'll see you next time

# %%
prediction = pipe("/opt/WorkSpace/whisper/voice/c++对象模型探索课程详细介绍.aac",
                  batch_size=4,
                  return_timestamps=True)
dickValue = prediction["chunks"]
for key in dickValue:
    print(str(key["timestamp"][0]) + " - " + str(key["timestamp"][1]) + "\t:" + key["text"])
# Out:
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# 0.0 - 1.56	:大家好
# 1.56 - 4.3	:非常高兴和大家见面
# 4.3 - 8.18	:这门课是老师的一门新课
# 8.18 - 11.14	:名字叫西佳佳对象模型探索
# 11.14 - 13.92	:也可以说是老师的第四门课
# 13.92 - 16.5	:前三门课分别是
# 16.5 - 18.54	:第一门课是西语言入门
# 18.54 - 22.12	:第二门课是咱们西佳佳从入门到精通
# 22.12 - 24.56	:西佳佳十一十四十七
# 24.56 - 25.42	:第三门课是西家家十一十四十七
# 25.44 - 26.3	:第三门课呢
# 26.3 - 29.72	:是西家家十一并发与多现成
# 29.72 - 33.32	:那么这门课叫西家家对象模型探索啊
# 33.32 - 35.66	:是老师的第四门课
# 35.66 - 36.68	:那么这门课呢
# 36.68 - 37.78	:他是一门啊
# 37.78 - 41.62	:有一定难度也有一定趣味性的这么一门课
# 42.86 - 45.8	:那么咱们现在讲的是这门课的第一章
# 45.8 - 49.58	:西加加对象模型探索课程介绍的第一节
# 49.58 - 53.1	:西加加对象模型探索课程详细介绍
# 53.1 - 54.66	:那本节课呢
# 54.66 - 56.66	:咱们会讲如下这六个问题
# 56.66 - 59.14	:前沿和学习效果
# 59.14 - 61.84	:西加加对象模型研究的是什么
# 61.84 - 64.52	:学习这门课程的基础要求
# 64.52 - 66.3	:简要自我介绍
# 66.3 - 67.92	:讲解参照
# 67.92 - 69.74	:演示环境说明
# 69.74 - 71.26	:好
# 71.26 - 72.06	:下面呢
# 72.06 - 73.64	:咱们开始讲第一个问题
# 73.64 - 76.0	:前沿和学习效果
# 76.0 - 84.56	:这个
# 84.56 - 86.94	:咱们这边课的标题
# 86.94 - 89.88	:大家注意是西加加对象模型探索
# 89.88 - 92.88	:西加加对象模型这个概念
# 92.88 - 94.32	:提起来的话
# 94.32 - 97.54	:我相信有一部分朋友可能会非常陌生
# 97.54 - 99.84	:甚至可能从来没听过
# 99.84 - 101.66	:我同时也相信
# 101.66 - 105.28	:还有另外一部分朋友非常熟悉
# 105.28 - 107.74	:但实际上
# 107.74 - 109.72	:西佳佳对象模型这个词
# 109.72 - 112.82	:可以说是久复盛名的
# 112.82 - 116.28	:熟悉的朋友一定读过一本书
# 116.28 - 117.28	:叫什么呢
# 117.28 - 120.62	:叫做深度探索西佳佳对象模型
# 120.62 - 122.96	:有这么一本书叫
# 120.64 - 123.0	:对象模型有这么一本书叫
# 123.0 - 130.3	:深度探索
# 130.3 - 131.84	:西加加对象模型
# 131.84 - 133.64	:它的英文呢
# 133.64 - 134.8	:就是inside
# 134.8 - 137.32	:the
# 137.32 - 138.72	:西加加
# 138.72 - 141.44	:object model
# 141.44 - 142.98	:它是这么一本书
# 142.98 - 144.64	:那么这本书呢
# 144.64 - 146.26	:可以说在咱们西加加界
# 146.26 - 148.44	:具有很高的美誉度
# 148.44 - 150.28	:借着这本书
# 150.28 - 153.32	:西加加对象模型
# 153.32 - 156.88	:这个概念就被大家慢慢熟悉了
# 156.88 - 159.18	:那么西加加对象模型
# 159.18 - 160.56	:它主要研究的是什么
# 160.56 - 163.84	:它主要研究的是很多
# 163.84 - 167.0	:不被外人所知的
# 167.0 - 170.0	:西佳佳对象内部工作原理
# 170.0 - 178.0	:研究西佳佳对象内部工作原理
# 178.0 - 184.0	:底层的一些具体实现机制方面的知识
# 184.0 - 188.02	:所以大家可以这么理解
# 188.02 - 191.66	:咱们这门西加加对象模型探索课程
# 191.66 - 193.12	:是属于什么呢
# 193.12 - 196.84	:是属于提高个人西加加开发修养
# 196.84 - 202.0	:提高个人西加加开发修养
# 202.0 - 208.14	:练习西加�佳编程内功
# 208.14 - 211.52	:一门课程
# 211.52 - 216.72	:是属于这样一门课程
# 216.72 - 221.68	:那学习这门课能达到一个什么样的效果呢
# 221.68 - 227.28	:学习效果啊
# 227.28 - 228.0	:老师呢
# 228.0 - 229.96	:认为主要有三个方面
# 229.96 - 233.36	:三方面啊
# 233.36 - 234.58	:哪三方面呢
# 234.58 - 235.62	:第一呢
# 235.62 - 237.34	:他能够啊
# 237.34 - 241.06	:在很大程度上拓展你的眼界和思路
# 241.06 - 245.62	:让你去了解
# 245.62 - 249.42	:在西加加很多表面代码的内部
# 249.42 - 250.94	:究竟干了一些什么事
# 250.94 - 252.54	:学习之后
# 252.54 - 255.36	:你会觉得自己的层次能力
# 255.36 - 257.86	:学习之后
# 257.86 - 259.46	:你会觉得
# 259.46 - 264.1	:自己的层次能力
# 264.1 - 268.86	:以及对西加加开发技术的技术的这个自信心
# 268.86 - 271.62	:都会提升一大截
# 271.62 - 275.38	:那这个感受呢
# 275.38 - 277.24	:它是属于潜移默化的
# 277.24 - 278.88	:需要大家自己去体会
# 278.88 - 281.22	:并且你肯定能体会到这一点
# 281.22 - 283.56	:这是第一个拓展眼界和思路
# 283.56 - 285.88	:第二呢就是
# 288.16 - 289.72	:应付面试
# 293.46 - 295.84	:这个大家很多朋友
# 295.84 - 300.0	:尤其是在这个参加工作的朋友都有过这个面试的经历啊
# 300.0 - 301.56	:找工作面试
# 301.56 - 302.8	:那么面试的时候呢
# 302.8 - 305.64	:偶尔可能碰到如下的情况
# 305.64 - 306.62	:什么情况呢
# 306.62 - 308.88	:比如说如果你技术比较菜的话
# 308.88 - 310.58	:那那个面试官啊
# 310.6 - 313.24	:就是那个搞技术的面试官不是人力资源
# 313.24 - 313.98	:那个啊
# 313.98 - 315.96	:那个搞技术的面试官啊
# 315.96 - 317.76	:他可能就鄙视你啊
# 317.76 - 319.32	:感觉你技术太菜
# 319.32 - 321.78	:那如果你这个在面试的时候啊
# 321.78 - 326.72	:在某些方面比这个面试官强那么一点点那他就会想办法压你
# 326.72 - 330.08	:他就会证明在某些方面他比你强
# 330.08 - 333.98	:这是我们偶尔会见到的一种面试官
# 333.98 - 336.16	:那还有一些面试官
# 336.16 - 337.94	:他的表现就是
# 337.94 - 341.96	:如果你表现出来了很强大的实力
# 341.96 - 344.26	:他会很欣赏你
# 344.26 - 347.8	:并且发自内心的想把你留下
# 347.8 - 349.48	:遇到这种面试官的话
# 349.48 - 352.48	:那么大家找工作找成功的几率就很大
# 352.48 - 352.96	:就很大
# 353.98 - 358.12	:那在这些不管是善意的面试官
# 358.12 - 360.94	:还是想压你一筹的面试官
# 360.94 - 362.62	:不管什么样的面试官
# 362.62 - 367.14	:那么往往他们有的时候就会问出来一些很刁钻的问题
# 367.14 - 368.18	:啊
# 368.18 - 369.66	:这个呃
# 369.66 - 370.3	:而且呢
# 370.3 - 375.62	:有些面试官会为自己能够问出这样刁钻的问题而洋洋得意的啊
# 375.62 - 377.42	:那在这些刁钻的问题中
# 377.42 - 384.32	:往往就包含了一些咱们要讲的这个西加加对象模型中的一些知识啊
# 384.32 - 385.5	:比如他可能问你
# 385.5 - 386.9	:问你什么呢
# 386.9 - 389.8	:说一个不包含任何成员的类
# 389.8 - 391.68	:他的sizeof是多大
# 391.68 - 394.28	:这是一种问法
# 394.28 - 396.5	:那有的时候呢
# 396.5 - 397.72	:这个问题比如说
# 397.72 - 398.72	:一个空类
# 398.72 - 400.1	:空的类
# 400.1 - 401.68	:sizeof是多大
# 401.68 - 404.82	:sizeof一个空类是多大
# 404.82 - 406.0	:那么或者是
# 406.0 - 407.28	:他也可能会问你
# 407.28 - 412.1	:比如说虚函数表的一些问题
# 412.1 - 413.48	:也可能会问
# 413.48 - 415.42	:诸如此类的
# 415.42 - 418.52	:那可以说如果你此前没有接触过
# 418.52 - 422.06	:这个C++对象模型方面的知识
# 422.06 - 425.02	:你很有可能回答不上来这种问题
# 425.02 - 427.16	:那如果回答不上来的话
# 427.16 - 428.9	:那可能在面试官眼中
# 428.9 - 430.8	:他就给你判定一个什么
# 430.8 - 432.58	:判定一个基础不牢
# 432.58 - 436.0	:那么你很有可能就会丢掉这个工作机会
# 436.6 - 437.78	:那这是第二点
# 437.78 - 439.54	:咱们学习是为了应付面试
# 439.54 - 441.3	:第三点
# 441.3 - 445.96	:就是人们所说的装逼
# 445.96 - 449.68	:这个词虽然比较糙
# 449.68 - 451.08	:但是这个道理不糙
# 451.08 - 452.82	:咱们做西家家
# 452.82 - 454.7	:开发这个行业
# 454.7 - 456.14	:你比别人牛
# 456.14 - 458.12	:那也是一个很自好的事
# 458.12 - 460.44	:但是话说回来
# 460.44 - 463.38	:不管你具备三五年的开发经验也好
# 463.38 - 465.76	:还是具备十年八年的开发经验甚至更五年的开发经验也好还是具备十年八年的开发经验
# 465.76 - 467.66	:甚至更久的开发经验
# 467.66 - 469.98	:如果你没研究过
# 469.98 - 474.22	:西加加对象内部的一些知识的话
# 474.22 - 477.6	:那么很可能一个很简单的
# 477.6 - 478.9	:西加加对象模型问题
# 478.9 - 480.54	:你就回答不上来
# 480.54 - 483.14	:这跟你工作年限没关系
# 483.14 - 484.82	:比如上面咱们谈到的一个空位
# 484.82 - 486.18	:你说的赛 of是多大
# 486.18 - 487.6	:如果你没研究这个问题
# 487.6 - 489.14	:你肯定回答不上来
# 489.14 - 490.88	:其实一个空类
# 490.88 - 492.78	:他的size of是一个字节
# 492.78 - 494.14	:是一个字节
# 494.14 - 497.86	:size of一个空类
# 497.86 - 499.86	:等于一个字节
# 499.86 - 502.7	:那么咱们看看
# 502.7 - 504.74	:有没有朋友回答错误的
# 504.74 - 506.38	:有没有朋友回答错误的有没有朋友回答错误的
# 506.38 - 508.62	:那么当然咱们在课程中会讲
# 508.62 - 509.7	:为什么它是一个字节
# 509.7 - 512.36	:所以综上所述
# 512.36 - 513.86	:老师认为
# 513.86 - 515.32	:作为一个对生活
# 515.32 - 516.64	:咱们充满激情
# 516.64 - 519.46	:想挑战一点技术难度的小伙伴
# 519.46 - 521.82	:或者是作为一个希望晋级
# 521.82 - 524.02	:成长为西佳佳高手
# 524.02 - 526.6	:甚至是大师级别的小伙伴
# 526.6 - 529.24	:那么西佳佳对象模型
# 529.24 - 531.22	:西佳佳对象模型
# 531.22 - 532.6	:这边课程
# 532.6 - 533.54	:这边知识
# 533.54 - 538.22	:都是非常难得和非常值得学习的
# 538.22 - 542.68	:这就是老师讲的第一个前沿和学习效果
# 542.68 - 544.1	:好
# 544.1 - 546.46	:那么咱们看一看第二个问题
# 546.46 - 549.06	:在这呢
# 549.06 - 549.7	:第二个问题
# 549.7 - 553.0	:西加加对象模型研究的是什么
# 563.48 - 565.36	:那么西加加对象模型啊
# 565.36 - 567.52	:到底是研究一个什么东西呢
# 567.52 - 570.5	:也就是说研究哪方面知识呢
# 570.5 - 573.18	:大家都知道西加加
# 573.18 - 576.42	:它是一门支持面向对象程序设计的语言
# 576.42 - 578.58	:那么这种支持啊
# 578.58 - 581.24	:肯定是需要系统内部的底层
# 581.24 - 583.78	:的各种各样的一些实现
# 583.78 - 585.4	:所以啊
# 585.4 - 586.92	:C++编译器啊
# 586.92 - 589.4	:在我们程序开发者的背后啊
# 589.4 - 591.42	:实际上是干了很多事情的
# 591.42 - 594.4	:比如我们生成对象的时候啊
# 594.4 - 595.94	:调用类的构造函数
# 595.94 - 597.66	:释放对象的时候
# 597.66 - 599.5	:调用类的吸构函数
# 599.5 - 602.24	:在我们没有定义自己的
# 602.24 - 603.7	:拷贝构造函数的时候
# 603.7 - 608.44	:编译器还会帮我们合成一个拷贝构造函数等等
# 608.44 - 611.08	:这一系列背后的动作
# 611.08 - 612.84	:那我们这门课呢
# 612.84 - 618.98	:研究的就是系统内部底层的各种各样的实现是如何来做的
# 621.24 - 628.42	:研究系统内部底层的各种各样的实现
# 628.42 - 630.58	:是如何来做的
# 630.58 - 634.42	:面向对象设计语言的突出特性
# 634.42 - 635.66	:是什么呢
# 635.66 - 638.42	:大家知道是既成性多了它也行
# 638.42 - 643.06	:这两个特性
# 643.06 - 646.68	:这两个特性它对具体实现细节是什么
# 646.68 - 649.48	:实现起来开销怎么样等等
# 649.48 - 652.72	:都是我们研究的话题
# 652.72 - 654.76	:那么既然呢
# 654.76 - 657.56	:咱们这门课是针对对象模型的探索
# 657.56 - 671.14	:我们呢就更多的围绕类对象来讨论问题更多的是围绕类对象来讨论
# 671.14 - 675.98	:按照大家正常的学习
# 675.98 - 678.74	:C++语言开发的学习旅程来讲
# 678.74 - 682.9	:可以说是可以不学习
# 682.9 - 686.22	:这些C++对象模型的知识可以不学习啊这些这个C++对象模型的知识
# 686.22 - 687.5	:可以不学习
# 687.5 - 693.78	:那么或者说你也学不到这些方面的知识
# 693.78 - 695.18	:所以呢
# 695.18 - 697.36	:咱们就开设这门课程啊
# 697.36 - 698.74	:来学习这方面的知识
# 698.74 - 701.32	:C++对象模型啊
# 701.32 - 702.36	:他这个知识啊
# 702.88 - 704.8	:这个整体来讲啊
# 704.8 - 708.98	:市面上的这些资料不是不是太多啊
# 708.98 - 710.88	:但是这些知识呢
# 710.88 - 715.36	:无形中能提高我们自身的这个整体素质啊
# 715.36 - 717.06	:他起到一个很关键的作用
# 717.06 - 719.86	:所以这个学或者不学
# 719.86 - 722.7	:完全取决于你自己的想法和决定
# 722.7 - 726.7	:这个就是老师把这门课定义成
# 726.7 - 729.04	:他是属于大师进阶
# 729.04 - 731.78	:这个课程之一的主要原因
# 731.78 - 734.82	:如果你只是用西佳佳
# 734.82 - 737.32	:来应付常规的日常开发
# 737.32 - 740.84	:你是可以不学西佳佳对象模型
# 740.84 - 741.56	:这些知识的
# 741.56 - 744.18	:但是如果你希望成长为
# 744.18 - 747.32	:大家比较公认的西加加高手啊
# 747.32 - 748.7	:甚至是大师的话
# 748.7 - 751.78	:那么这门课是必须要学的
# 751.78 - 754.02	:或者换句话来说
# 754.02 - 760.32	:这门课其实主要还是针对这个西加加编程经验比较丰富
# 760.32 - 763.56	:并且希望进一步提高自己这个认知
# 763.56 - 768.78	:希望进一步了解系统底层干了什么的老四级
# 773.78 - 783.9	:本门课程针对西加加编程经验比较丰富
# 783.9 - 788.54	:并希望进一步提高自己认知
# 788.54 - 793.86	:希望进一步了解系统底层
# 793.86 - 795.48	:干了什么的
# 799.48 - 800.2	:老司机
# 800.2 - 802.26	:应该这么说
# 802.26 - 805.98	:想进一步提高自己的开发实力
# 805.98 - 806.98	:这样的老司机
# 806.98 - 807.72	:好
# 807.72 - 809.14	:这个就是咱们讲的
# 809.14 - 809.94	:第二个问题
# 809.94 - 812.66	:西加加对象模型研究的是什么
# 812.66 - 815.6	:他就是围绕这一堆来研究
# 815.6 - 816.5	:来讨论
# 816.5 - 818.18	:好
# 818.18 - 819.5	:第二个问题咱们就讲完了
# 819.5 - 821.46	:咱们讲一下第三个问题
# 821.46 - 824.08	:学习这门课程的基础要求
# 821.42 - 824.0	:咱们讲一下第三个问题学习这门课程的基础要求
# 824.56 - 829.98	:学习这门课
# 829.98 - 833.12	:不要求大家对西佳佳11
# 833.12 - 836.42	:14 17新标准有过多的掌握
# 836.42 - 839.22	:但是大家要对于传统西佳佳
# 839.22 - 841.0	:也就是西佳佳98
# 841.0 - 842.48	:这个版本
# 842.48 - 844.6	:地语言开发要比较熟
# 844.6 - 845.64	:比如说
# 845.64 - 847.24	:大家对这个类
# 847.24 - 847.86	:是吧
# 847.86 - 848.76	:类这个概念
# 848.76 - 850.8	:对象
# 850.8 - 852.2	:记程
# 852.2 - 853.6	:虚函数
# 853.6 - 855.58	:虚极类
# 855.58 - 858.0	:等等
# 858.0 - 858.96	:这些概念
# 858.96 - 862.64	:都要有一个相对比较熟悉的
# 862.64 - 863.78	:认知
# 863.78 - 864.94	:或者说是了解
# 864.94 - 868.3	:老师希望学这门课的朋友们
# 868.3 - 871.34	:大家至少要用过一到两年的西加加
# 871.34 - 879.88	:然后当大家对自己的能力进行一个比较客观
# 879.88 - 881.88	:或者说是常规的评估的时候
# 881.88 - 885.68	:认为自己能够达到一种终极应用水平
# 885.68 - 890.72	:大家自己去体会
# 890.72 - 891.74	:这个终极应用水平
# 891.74 - 892.96	:应该是一个什么样的水平
# 892.96 - 895.4	:如果大家认为自己知识积累
# 895.4 - 896.34	:还不太够的话
# 896.34 - 898.84	:那老师向大家推荐
# 898.84 - 901.36	:我的另外一门课程
# 901.36 - 901.88	:就是
# 901.88 - 905.1	:西佳佳从入门课程就是西佳佳
# 905.1 - 906.86	:从入门
# 906.86 - 909.9	:到精通
# 909.9 - 912.94	:西佳佳十一
# 912.94 - 913.82	:十四
# 913.82 - 914.56	:十七
# 914.56 - 915.36	:这门课
# 915.36 - 918.04	:这门课里边不但讲传统的
# 918.04 - 919.28	:西佳佳九八
# 919.28 - 920.86	:还讲了西佳佳新标准
# 920.86 - 921.8	:十一十四十七
# 921.8 - 923.56	:这是一门也是老师的一门
# 923.56 - 925.06	:非常优质的课程
# 925.06 - 927.2	:这个课程就很贴近
# 927.2 - 931.68	:很很适合于初学西加加的学习者来学
# 931.68 - 933.2	:并且学完之后
# 933.2 - 936.84	:你就能够能够达到一个西加加的中高级开发水平
# 936.84 - 942.02	:非常适合这个打这个西加加开发基础
# 942.02 - 948.46	:那么这门课程在这个学员中也有一个非常良好的口碑啊
# 948.46 - 948.84	:好
# 948.84 - 950.38	:这个就是老师讲的啊
# 950.38 - 954.34	:第三个问题学习咱们的西街家对象模型啊
# 954.34 - 956.96	:这门课程探索这门课程啊
# 956.96 - 962.76	:对基础要求希望大家对这些概念要比较熟比较熟啊
# 962.76 - 973.56	:第四个问题简要自我介绍
# 975.18 - 977.7	:因为老师刚刚过了生日所以可以说至今为止
# 977.7 - 979.46	:老师已经干了24年了
# 979.46 - 980.62	:24年习家家
# 980.62 - 982.12	:老司机
# 982.12 - 984.4	:主要领域
# 984.4 - 987.52	:老师的工作领域就在电信啊
# 987.52 - 988.16	:电信领域
# 989.36 - 990.86	:这个网络安全领域
# 993.44 - 995.1	:以及网络游戏领域
# 996.94 - 999.4	:网络上可能还至今还存在一个冒险之路
# 1000.5 - 1001.38	:这个啊
# 1001.38 - 1002.4	:全球同福的
# 1006.3 - 1008.82	:网络游戏这个就是老师开发的
# 1008.82 - 1011.06	:主要就是老师自己的开发
# 1011.06 - 1011.92	:是一个独立游戏
# 1011.92 - 1016.92	:那么老师经历过很多项目
# 1016.92 - 1019.38	:其中有些项目还很庞大
# 1019.38 - 1021.14	:有老师独立完成的
# 1021.14 - 1023.66	:可以说一个人一般驾驭几十万号代码
# 1023.66 - 1025.94	:都是一个很家常便饭的事
# 1025.94 - 1028.76	:那我这个老师呢
# 1028.76 - 1030.52	:跟很多其他老师也不一样
# 1030.52 - 1033.7	:我这个比较有讲课的天赋
# 1033.7 - 1035.54	:这个是遗传的
# 1035.54 - 1038.62	:这个我们家族有很多人都是老师
# 1038.62 - 1041.88	:所以我讲课的特点就是
# 1041.88 - 1044.44	:这个比较精准到位
# 1044.44 - 1046.24	:我讲课的特点就是这个比较精准到位我讲课的特点是精准到位
# 1046.24 - 1050.36	:这个以少为多
# 1050.36 - 1055.8	:以少为多
# 1055.8 - 1058.1	:这个以少为多
# 1058.1 - 1059.72	:就是什么意思呢
# 1059.72 - 1060.82	:就是我只跟你讲
# 1060.82 - 1062.12	:你有必要知道的东西
# 1062.12 - 1064.28	:我不会触及的太多
# 1064.28 - 1065.2	:太深
# 1065.2 - 1067.32	:以免把你本来明白的事
# 1067.32 - 1068.78	:给你讲糊涂了
# 1068.78 - 1071.38	:其实我发现当一个合格的老师
# 1071.38 - 1072.5	:真的是有难度
# 1072.5 - 1073.9	:很大一部分老师
# 1073.9 - 1075.34	:他们自己是明白的
# 1075.34 - 1077.28	:但是他要是讲出来的话
# 1077.28 - 1078.42	:你就听不明白
# 1078.42 - 1080.58	:越复杂的知识点
# 1080.58 - 1082.6	:这一点就体现的越明显
# 1082.6 - 1084.44	:他越能讲的让你听不懂
# 1084.44 - 1087.02	:所以有一句话叫什么
# 1087.02 - 1089.24	:叫没有比较就没有伤害
# 1089.24 - 1092.2	:相信听过其他老师讲过的朋友
# 1092.2 - 1094.16	:也会不自觉的是吧
# 1094.16 - 1097.46	:拿其他老师跟我做比较
# 1097.46 - 1100.22	:看一看谁讲的能讲明白
# 1100.22 - 1101.12	:谁没讲明白
# 1101.12 - 1103.74	:不过本老师有信心
# 1103.74 - 1105.1	:把大家教明白老师也相信大家会本老师有信心把大家教明白
# 1105.1 - 1106.84	:老师也相信
# 1106.84 - 1109.16	:大家会给老师的课程
# 1109.16 - 1110.56	:一个比较客观
# 1110.56 - 1114.0	:公正和高质量的评价
# 1114.0 - 1115.16	:高质量评价
# 1115.16 - 1115.84	:好
# 1115.84 - 1117.1	:这个就是老师讲的
# 1117.1 - 1117.96	:简要自我介绍
# 1117.96 - 1119.38	:咱们看一看
# 1119.38 - 1120.22	:讲解参照
# 1129.64 - 1132.08	:老师在这边课程中啊有两方面的主要参照啊
# 1132.08 - 1135.92	:第一方面就是咱们前面说过的这本书
# 1135.92 - 1138.74	:深度探索西加加对象模型
# 1138.74 - 1152.42	:稍等老实说个
# 1152.42 - 1153.6	:这本
# 1153.6 - 1160.3	:这本书是非常知名的一本书
# 1160.3 - 1161.36	:它的作者是
# 1161.36 - 1161.98	:Lip
# 1161.98 - 1166.6	:这样一位作者那么这位作者是Lip这样一位作者
# 1166.6 - 1167.8	:那么这位作者
# 1167.8 - 1170.22	:他参与设计了世界上第一套
# 1170.22 - 1171.46	:西加加编译器
# 1171.46 - 1174.06	:所以这是一个大师级的人物
# 1174.06 - 1175.8	:这本书的翻译
# 1175.8 - 1178.0	:是由台湾知名的老师
# 1178.0 - 1179.6	:侯杰老师来翻译的
# 1179.6 - 1183.76	:这本书很多读者都读过
# 1183.76 - 1187.0	:可能在当当甚至在一些书评网站
# 1187.0 - 1189.34	:可能大概有几千的书评
# 1189.34 - 1190.48	:书评非常多
# 1190.48 - 1194.74	:很多读者非常喜欢这本书
# 1194.74 - 1197.64	:但是呢也普遍的反映一些问题
# 1197.64 - 1200.74	:比如说读起来内容比较晦涩
# 1200.74 - 1203.9	:翻译的时候可能也有一些问题等等
# 1203.9 - 1206.3	:老师认为啊
# 1206.3 - 1207.58	:这个不管怎么说啊
# 1207.58 - 1208.84	:这个瑕不掩瑜吧
# 1208.84 - 1209.62	:啊
# 1209.62 - 1210.74	:老师呢
# 1210.74 - 1213.06	:这个觉得这本书还是很棒的
# 1213.06 - 1213.7	:很棒的
# 1213.7 - 1214.28	:呃
# 1214.28 - 1215.26	:这个呃
# 1215.26 - 1218.16	:所以老师讲解的时候会参照这本书啊
# 1218.16 - 1220.04	:参照的原则就是什么呢
# 1220.04 - 1223.14	:就是只给大家介绍老师啊
# 1223.14 - 1224.5	:认为有用的
# 1224.5 - 1227.32	:大家需要知道的啊
# 1227.32 - 1231.72	:能够通过演示翻例来证明这个书里边的描述是真的
# 1231.72 - 1233.06	:这样的内容啊
# 1233.06 - 1235.9	:老师讲的原则是参照的原则是什么啊
# 1235.9 - 1240.82	:是老师认为啊
# 1240.82 - 1242.04	:对大家有用的
# 1242.04 - 1244.38	:然后呢
# 1244.38 - 1246.04	:大家需要知道的
# 1246.04 - 1248.08	:能够通过
# 1248.08 - 1249.8	:演示范例
# 1249.8 - 1252.72	:证明的
# 1252.72 - 1254.5	:你比如你讲一个知识理论
# 1254.5 - 1255.86	:但是你范例演示不出来
# 1255.86 - 1258.06	:所以你也不知道这理论是对还是错
# 1258.06 - 1260.54	:那这个就讲的必要性
# 1260.54 - 1261.4	:就显得小了
# 1261.4 - 1261.7	:是吧
# 1261.7 - 1263.62	:演示范例证明的
# 1263.62 - 1264.96	:证明是真的
# 1264.96 - 1265.0	:这样的内容就显得小了是吧演示范例证明的证明是真的
# 1265.0 - 1268.26	:这样的内容
# 1268.26 - 1273.38	:那么相反一些蒙了两可的
# 1273.38 - 1275.14	:可知道可不知道的
# 1275.14 - 1277.26	:或者难以证明真假的话题
# 1277.26 - 1279.36	:难以证明真假的话题
# 1279.36 - 1281.12	:咱们可能就不介绍
# 1281.12 - 1281.64	:是吧
# 1281.64 - 1284.24	:如果有的朋友认为
# 1284.24 - 1285.04	:买了这本书是吧你可能没读懂或者是吧这个如果有的朋友认为啊
# 1285.04 - 1286.24	:买了这本书是吧
# 1286.24 - 1287.52	:你可能没读懂
# 1287.52 - 1289.62	:或者是你花了十分力气
# 1289.62 - 1292.6	:你弄懂了其中六分的内容
# 1292.6 - 1294.88	:那么老师这门啊
# 1294.88 - 1298.5	:咱们讲的西佳佳对象不行探索这门课
# 1298.5 - 1303.04	:那么存在的意义就是老师能够让你只花两分力气
# 1303.04 - 1306.72	:你就能明白其中的八分到十分内容
# 1306.72 - 1310.58	:同时让你额外的收获到老师
# 1310.58 - 1313.8	:针对于西加压对象模型的一些理解
# 1313.8 - 1318.28	:一些心得体会和一些新的知识点
# 1318.28 - 1321.06	:那么这个是第一点
# 1321.06 - 1322.14	:讲解的参照
# 1322.14 - 1330.86	:第二个讲解参照就是老师会参照网络上的各种资料
# 1330.86 - 1333.38	:各种和西佳佳对象模型有关的资料
# 1333.38 - 1336.8	:网上其实是有大量的朋友
# 1336.8 - 1341.58	:和很多深爱西佳佳对象模型知识的朋友
# 1341.58 - 1345.3	:他们做了各种各样的学习和研究
# 1345.3 - 1347.76	:甚至有的人研究的非常深入
# 1347.76 - 1348.8	:所以呢
# 1348.8 - 1351.34	:老师当然也不能放过这样的知识点
# 1351.34 - 1355.12	:结合网上各种各样的这些相关资料
# 1355.12 - 1357.2	:通过整理消化
# 1357.2 - 1362.02	:这个老师会整理消化
# 1362.02 - 1363.1	:然后呢
# 1363.1 - 1369.0	:把最精华的东西分享给大家
# 1369.0 - 1371.5	:在这门课程中分享给大家
# 1371.5 - 1372.68	:目的只有一个
# 1372.68 - 1374.7	:就是让大家用最少的时间
# 1374.7 - 1378.0	:掌握最多的最有用的知识
# 1378.0 - 1379.4	:因为对于大家来讲
# 1379.4 - 1380.6	:最宝贵的是什么
# 1380.6 - 1383.0	:最宝贵的其实就是时间
# 1383.0 - 1384.0	:尤其是参加工作
# 1384.0 - 1385.82	:你就以后这些朋友可能在大学的时候你体会�其是参加工作你就以后这些朋友
# 1385.82 - 1387.2	:可能在大学的时候
# 1387.2 - 1388.26	:你体会不了这么神
# 1388.26 - 1389.64	:参加工作的朋友
# 1389.64 - 1390.82	:尤其是那些天天加班
# 1390.82 - 1392.84	:有的时候一周上六天
# 1392.84 - 1394.3	:每天加班到11点的朋友
# 1394.3 - 1395.48	:你就知道了
# 1395.48 - 1397.8	:时间对于你来讲太宝贵了
# 1397.8 - 1400.66	:可能忙的你都没有时间来学习
# 1400.66 - 1402.28	:和提高自己的能力了
# 1402.28 - 1403.8	:天天就忙公司的事
# 1403.8 - 1405.62	:就忙到这个程度
# 1405.62 - 1407.72	:老师要强调
# 1407.72 - 1409.56	:咱们在讲这门
# 1409.56 - 1412.36	:吸加加对象模型探索课程的时候
# 1412.36 - 1414.36	:会融入很多新东西
# 1414.36 - 1417.08	:包括老师自己的思考
# 1417.08 - 1418.26	:体会
# 1418.26 - 1421.94	:并且老师会逐个的问题来
# 1421.94 - 1424.02	:亲自的来演示和示范
# 1424.02 - 1425.66	:咱们不是光讲咱们是要写亲自的来演示和示范咱们不是光讲
# 1425.66 - 1428.18	:咱们是要写代码来演示
# 1428.18 - 1430.06	:来示范讲的这些理论的
# 1430.06 - 1431.44	:所以呢
# 1431.44 - 1432.6	:老师这门课
# 1432.6 - 1434.66	:相信大家不会觉得晦涩
# 1434.66 - 1439.0	:同时通过各种各样的老师书写的范例
# 1439.0 - 1441.36	:这个大家呢
# 1441.36 - 1444.8	:能够进一步的体会到西加加
# 1444.8 - 1446.72	:这个西加加对象模型
# 1446.72 - 1449.82	:探索这门课程的一个乐趣
# 1449.82 - 1453.38	:这门课程其实是很有乐趣的
# 1453.38 - 1454.9	:因为探索一个东西
# 1454.9 - 1457.46	:它是比较有趣的
# 1457.46 - 1458.5	:好
# 1458.5 - 1461.0	:这个是老师讲的第五个问题
# 1461.0 - 1463.1	:讲解参照
# 1463.1 - 1464.48	:第六个问题
# 1464.48 - 1466.14	:演示环境说明
# 1466.14 - 1473.72	:老师讲这本课程
# 1473.72 - 1475.4	:刚才也说了
# 1475.4 - 1476.84	:咱们避免不了做演示
# 1476.84 - 1478.64	:老师演示的时候
# 1478.64 - 1479.78	:会以Windows平台
# 1479.78 - 1483.38	:为主
# 1483.38 - 1485.14	:来演示为主为主
# 1485.14 - 1488.16	:来演示
# 1488.16 - 1492.44	:但是考虑到咱们这门知识的复杂性
# 1492.44 - 1497.46	:当Windows和Linux
# 1497.46 - 1499.32	:这两大主要的平台
# 1499.32 - 1501.3	:差异比较明显的时候
# 1501.3 - 1513.74	:老师有的时候会在Linux平台上也做演示
# 1514.82 - 1516.14	:做演示不演示啊
# 1516.14 - 1518.36	:这个这个具体演示
# 1518.36 - 1520.4	:咱们就具体情况地理分析啊
# 1520.4 - 1521.48	:啊
# 1521.48 - 1523.0	:这个以Vin的最主啊
# 1523.0 - 1525.42	:Linux平台演示为辅就是这么一个意思
# 1525.42 - 1528.04	:那么Windows平台上
# 1528.04 - 1530.52	:老师演示的主要环境是VS2017
# 1530.52 - 1532.74	:这是在Windows平台上的
# 1532.74 - 1534.68	:C++开发环境
# 1534.68 - 1536.4	:其实VS2017
# 1536.4 - 1537.68	:它是一个集成开发环境
# 1537.68 - 1538.86	:它可以开发很多的
# 1538.86 - 1541.16	:语言所输出的代码
# 1541.16 - 1543.24	:咱们C++主要就是在
# 1543.24 - 1544.74	:开发环境中写
# 1544.74 - 1546.72	:这个环境非常棒
# 1546.72 - 1548.18	:调试非常方便
# 1548.18 - 1549.88	:调试方便
# 1549.88 - 1551.82	:就意味着给大家讲解的时候
# 1551.82 - 1553.6	:咱们演示起来特别方便
# 1553.6 - 1555.18	:大家特别容易
# 1555.18 - 1558.42	:能懂老师演示的内容
# 1558.42 - 1560.32	:这个VS2那一期
# 1560.32 - 1561.96	:大家注意这个呢
# 1561.96 - 1564.22	:它是有免费的社区版的
# 1564.22 - 1567.32	:社区版是免费的
# 1567.32 - 1569.08	:就那个community是吧
# 1569.08 - 1570.4	:UNITY吧
# 1570.4 - 1571.78	:它好像应该是这么拼的
# 1571.78 - 1572.78	:community这个版本
# 1572.78 - 1577.18	:大家可以一般可以通过网络来安装这个VS2017
# 1577.18 - 1579.96	:因为你通过网络安装的话
# 1579.96 - 1582.24	:可能要通过网络来下载
# 1582.24 - 1585.78	:整个的安装可能大概要需要两到四个小时
# 1585.78 - 1587.26	:而且吸盘的空间呢
# 1590.02 - 1591.52	:建议在20G以上啊
# 1593.44 - 1595.0	:这个老师呢
# 1595.0 - 1597.88	:在这里不准备带大家安装这个VS217
# 1597.88 - 1601.56	:大家自行的百度搜索这个如何安装VS217
# 1601.56 - 1604.8	:安装的时候大家注意有一些选项啊
# 1604.8 - 1605.56	:安装选项
# 1605.56 - 1609.36	:有一些西佳佳
# 1609.36 - 1611.48	:开发有关的
# 1611.48 - 1614.06	:我们就选
# 1614.06 - 1616.32	:一般的这样的开发选项
# 1616.32 - 1618.22	:都是带西佳佳这个字样的
# 1618.22 - 1620.66	:如果和西佳佳开发无关的选项
# 1620.66 - 1621.94	:就不要勾选
# 1621.94 - 1627.26	:和西佳佳无关的选项不要勾选�啊这个和西家家无关的选项不要勾选
# 1627.26 - 1628.58	:如果大家真的确定不了
# 1628.58 - 1629.9	:那就联系老师啊
# 1629.9 - 1631.04	:通过这个QQ也好
# 1631.04 - 1632.72	:通过其他的任何方式也好
# 1632.72 - 1633.82	:联系到老师啊
# 1633.82 - 1636.82	:这个这个或者是在网上咨询一些啊
# 1636.82 - 1639.02	:这个安装过为二十七的人士啊
# 1639.02 - 1641.24	:看看他们勾选了哪些项啊
# 1641.24 - 1642.68	:你千万不要全安装
# 1642.68 - 1643.4	:要全装的话
# 1643.4 - 1645.24	:可能你可能你需要个硬盘空间
# 1645.24 - 1646.86	:需要个百八十G的
# 1646.86 - 1648.96	:他在吸盘上可能还要占好几十G
# 1648.96 - 1650.18	:那就比较麻烦了
# 1650.18 - 1651.1	:也不必要啊
# 1651.1 - 1653.36	:不必要把系统深度有可能装装乱了
# 1653.36 - 1655.0	:所以这个只装啊
# 1655.0 - 1657.66	:跟吸解架开发有关的这个选项啊
# 1657.66 - 1658.7	:啊
# 1658.7 - 1661.54	:反正你装少了没问题啊
# 1661.54 - 1662.14	:装多了
# 1662.14 - 1663.56	:你你当然装多了
# 1663.56 - 1664.54	:你也可以卸载啊
# 1664.54 - 1665.4	:你装少了你可以后续再用那个干安装程序再再补充安装少了没问题啊装多了你你当然装多了你也可以卸载啊你做少了
# 1665.4 - 1667.6	:你可以后续再用那个干安装程序
# 1667.6 - 1670.08	:再再补充安装都可以啊
# 1670.08 - 1671.76	:大家也不用太担心啊
# 1671.76 - 1672.24	:当然了
# 1672.24 - 1674.6	:有些同学电脑上可能不是为了三零七
# 1674.6 - 1676.38	:可能有了这个VS2010啊
# 1676.38 - 1677.7	:VS2012啊
# 1677.7 - 1679.28	:因为咱们这边课比较传统
# 1679.28 - 1682.08	:咱们也不需要用到太新的西加加标准
# 1682.08 - 1682.52	:所以呢
# 1682.52 - 1683.72	:VS2010啊
# 1683.72 - 1687.24	:1022012甚至VS2005都有可能能用
# 1687.24 - 1689.48	:大家都可以先尝试着用一用
# 1689.48 - 1690.7	:如果不行再说
# 1690.7 - 1692.14	:不行再说
# 1692.14 - 1693.38	:这个在Linux上
# 1693.38 - 1695.42	:咱们刚才这个VS2017
# 1695.42 - 1696.68	:是在Windows平台
# 1696.68 - 1697.98	:Linux这个平台
# 1697.98 - 1701.7	:老师也是随便装了一个Ubuntu
# 1701.7 - 1703.7	:Ubuntu怎么拼的
# 1703.7 - 1705.28	:咱们就中文Ubuntu老师记了很久也没记住Ubuntu怎么拼UbuntuUbuntu怎么拼了咱们就中文
# 1705.28 - 1706.02	:Ubuntu
# 1706.02 - 1707.78	:老师记了很久也没记住
# 1707.78 - 1708.62	:Ubuntu怎么拼
# 1708.62 - 1709.8	:Ubuntu Linux
# 1709.8 - 1713.6	:这个老师在这个电脑上装了个虚拟机
# 1713.6 - 1715.58	:虚拟机里边装了个Ubuntu Linux
# 1715.58 - 1717.9	:然后咱们就在这个操作系统
# 1717.9 - 1722.66	:下面演示咱们Linux下的C++
# 1722.66 - 1724.24	:对编译和运行
# 1724.24 - 1729.1	:老师在这个Ubuntu上装了一个GCC和这个G++
# 1729.1 - 1729.52	:是吧
# 1729.52 - 1730.18	:咱们就用
# 1730.18 - 1731.52	:因为咱们是C++程序
# 1731.52 - 1732.72	:咱们就用G++来编译
# 1732.72 - 1733.56	:来编译就行了
# 1733.56 - 1733.98	:是吧
# 1733.98 - 1738.66	:如果这个大家没有玩过这个Linux的这个同学们
# 1738.66 - 1739.8	:这个老师呢
# 1739.8 - 1742.5	:也不太建议你去搭建这个开发环境
# 1742.5 - 1746.64	:因为没有玩过这个操作系统的这个人来说他这个搭建这个开发环境啊因为没有玩过这个操作系统的人来说
# 1746.64 - 1749.7	:他搭建这个开发环境还是有点小复杂的
# 1749.7 - 1752.28	:你看老师给你演示结果就行了
# 1752.28 - 1752.82	:是吧
# 1752.82 - 1754.64	:也能达到这个学习效果
# 1754.64 - 1757.74	:当然如果说你自己能搭建出来
# 1757.74 - 1759.08	:这个Linux开发环境
# 1759.08 - 1759.76	:那就更好
# 1759.76 - 1760.54	:是吧
# 1760.54 - 1763.46	:在这里老师也不准备带大家搭建
# 1763.46 - 1766.48	:这个Linux家的西加加开发环境
# 1766.48 - 1769.0	:因为咱们这门课重点不是
# 1769.0 - 1773.0	:以Linux的西加加开发为主
# 1773.0 - 1774.78	:不是这么样一门课
# 1774.78 - 1777.18	:现在老师就假定
# 1777.18 - 1779.5	:大家在电脑上
# 1779.5 - 1781.88	:已经成功的安装了
# 1781.88 - 1784.38	:VS的集成开发环境
# 1784.38 - 1786.42	:比如老师这个电脑上
# 1786.42 - 1790.6	:就已经安装好了VH Studio
# 1790.6 - 1792.1	:就是VS2017
# 1792.1 - 1797.52	:咱们现在把开发环境咱们设置一下
# 1797.52 - 1801.78	:咱们设置成适合于咱们西佳佳的开发环境
# 1801.78 - 1803.04	:咱们看怎么设置
# 1803.04 - 1806.64	:装完之后咱们双点这个桌面的VS2017
# 1806.64 - 1808.22	:双点VS2017
# 1808.22 - 1810.18	:然后呢
# 1810.18 - 1813.76	:咱们跟着老师进行以下的这个操作
# 1813.76 - 1815.72	:怎么操作呢
# 1815.72 - 1816.94	:看工具
# 1816.94 - 1819.44	:菜单上有个工具是吧
# 1819.44 - 1820.96	:导入和导出设置
# 1820.96 - 1822.12	:选一下
# 1822.12 - 1824.72	:然后弹出一个对话框
# 1824.72 - 1825.56	:咱们看下边下边有重置所有设置咱们选这个重置出设置选一下然后弹出一个对话框咱们看下边
# 1825.56 - 1827.7	:下边有重置所有设置
# 1827.7 - 1829.76	:咱们选这个重置所有设置
# 1829.76 - 1830.94	:然后呢
# 1830.94 - 1832.14	:选择这个
# 1832.14 - 1836.34	:下一步
# 1836.34 - 1838.0	:然后呢
# 1838.78 - 1840.02	:这块选择
# 1840.02 - 1840.6	:否
# 1840.6 - 1842.76	:仅重置设置
# 1842.76 - 1844.1	:从而覆盖我当前的设置
# 1844.1 - 1846.2	:然后这块点下一步
# 1846.2 - 1850.6	:然后这边有很多的开发环境
# 1850.6 - 1851.26	:开发语言
# 1851.26 - 1852.1	:JavaScript
# 1852.1 - 1853.0	:VB等等
# 1853.0 - 1855.18	:咱们就选这里边的Virtual C++
# 1855.18 - 1857.5	:如果大家看不到这个选项的话
# 1857.5 - 1860.28	:很有可能是你安装那时候没装全
# 1860.28 - 1862.48	:这个时候你要重新执行安装程序
# 1862.48 - 1865.48	:把相关的C++选项要装上才行
# 1865.48 - 1865.94	:好
# 1865.94 - 1868.72	:咱们选这个VHC++这一项
# 1868.72 - 1870.6	:然后选择完成
# 1870.6 - 1875.86	:这样的话系统可能要配置几秒钟
# 1875.86 - 1877.18	:配置几秒钟之后
# 1877.18 - 1878.68	:它就把一些配置信息
# 1878.68 - 1881.58	:就记录到一些配置文件中去了
# 1881.58 - 1885.98	:现在咱们就在这个VS2017
# 1885.98 - 1887.94	:咱们这个环境中
# 1887.94 - 1889.34	:咱们要创建一个工程
# 1889.34 - 1891.48	:为什么要创建一个工程啊
# 1891.48 - 1894.72	:因为这个熟悉这个编译环境的朋友都知道
# 1894.72 - 1895.86	:这个工程啊
# 1895.86 - 1899.42	:是咱们VS2017管理的这个基本单位
# 1899.42 - 1900.58	:管理的基本单位
# 1900.58 - 1902.36	:所以咱们创建一工程
# 1902.36 - 1904.1	:咱们大家看一看
# 1904.1 - 1904.96	:咱们创建啊
# 1904.96 - 1906.0	:老师带着大家创建一个工程这个因为创建一工程咱们大家看一看怎么创建老师带着大家创建一个工程
# 1906.0 - 1908.0	:因为创建一个工程之后
# 1908.0 - 1911.0	:方便咱们后续的课程演示
# 1911.0 - 1912.0	:选择什么
# 1912.0 - 1913.0	:文件是吧
# 1913.0 - 1915.0	:新建项目
# 1915.0 - 1916.0	:这个工程就是项目
# 1916.0 - 1917.0	:项目就是工程
# 1917.0 - 1919.0	:咱们先先先这么理解
# 1919.0 - 1922.0	:大家这个好新建项目
# 1924.0 - 1925.08	:然后等几秒钟左右左边咱们看这块有个virtuals项目
# 1926.2 - 1930.6	:然后等几秒钟左右左边咱们看这块有个virtus++
# 1930.6 - 1932.52	:如果没有virtus++
# 1932.52 - 1933.78	:咱们看看其他语言里有没有
# 1933.78 - 1935.26	:如果其他语言里也没有
# 1935.26 - 1936.38	:那证明你没装全
# 1936.38 - 1941.6	:还得考虑增补一些安装的选项
# 1942.32 - 1943.16	:virtus++
# 1943.16 - 1944.5	:右侧咱们选择一个什么
# 1944.5 - 1945.14	:选择一个什么选择一个
# 1945.14 - 1947.24	:Windows
# 1947.24 - 1949.62	:控制他应用程序就可以了
# 1949.62 - 1951.46	:然后这里边名称
# 1951.46 - 1952.88	:咱们给起一个什么名
# 1952.88 - 1953.68	:咱们起一个
# 1953.68 - 1954.44	:比如说project
# 1954.44 - 1957.14	:这里给个100
# 1957.14 - 1958.06	:是吧
# 1958.06 - 1959.72	:然后呢
# 1959.72 - 1961.34	:这块位置咱们给一个什么
# 1961.34 - 1962.64	:位置咱们给一个范例
# 1962.64 - 1965.08	:咱们给一个自己建个目录给个范例咱们给一个自己建个目录
# 1965.08 - 1966.28	:给个范例位置
# 1966.28 - 1967.08	:然后解决方案
# 1967.08 - 1968.72	:这大家注意看解决方案
# 1968.72 - 1971.16	:这咱们可以给一个solution
# 1973.36 - 1976.96	:100可以这样实际上一个解决方案
# 1976.96 - 1978.28	:解决方案是这个
# 1978.28 - 1980.4	:这个virtuals有管理单位
# 1980.4 - 1982.92	:一个解决方案里可以对应着
# 1982.92 - 1984.84	:咱们现在不是创建一个项目吗
# 1984.84 - 1987.62	:一个解决方案你可以对应着若干个项目它是这么一个包含关系解决方案里可以对应着咱们现在不是创建一个项目吗一个解决方案里可以对应着若干个项目
# 1987.62 - 1989.04	:它是这么一个包含关系
# 1989.04 - 1989.94	:解决方案更大
# 1989.94 - 1991.0	:项目更小
# 1991.0 - 1992.28	:那么一个项目
# 1992.28 - 1994.8	:它就生成一个可执行文件
# 1994.8 - 1997.86	:那么这个项目里就包含若干的
# 1997.86 - 1998.96	:这个原代码文件
# 1998.96 - 2001.5	:最终能生成一个可执行文件
# 2001.5 - 2002.76	:就是这么样一个东西
# 2002.76 - 2004.22	:这个就叫项目
# 2004.22 - 2005.36	:好咱们点击确定点击确定之后呢生成一个可执行文件就是这么样一个东西这个就叫项目好
# 2005.36 - 2006.24	:咱们点击确定
# 2006.24 - 2009.18	:点击确定之后
# 2009.18 - 2011.22	:咱们这里要等待几秒钟
# 2011.22 - 2014.22	:系统就自动替咱们创建一个项目
# 2014.22 - 2015.24	:创建一个项目
# 2015.24 - 2017.18	:也就是咱们所说的工程
# 2017.18 - 2017.9	:工程
# 2017.9 - 2019.36	:好
# 2019.36 - 2019.94	:等一等
# 2019.94 - 2020.36	:等一等
# 2020.36 - 2025.1	:这块稍微有点慢稍微有点慢
# 2025.1 - 2025.8	:稍微有点慢
# 2025.8 - 2033.8	:等了好几秒钟
# 2033.8 - 2035.24	:这个系统出来了
# 2035.24 - 2036.66	:咱们大家看了
# 2036.66 - 2038.74	:这块就是咱们创建解决方案
# 2038.74 - 2040.32	:这个下边就是项目
# 2040.32 - 2041.16	:也就是工程
# 2041.16 - 2042.44	:你看一个解决方案中
# 2042.44 - 2043.78	:现在是包含一个工程
# 2043.78 - 2045.36	:其实它可以包含很多工程这个解决方案中还可以新建工程你看一个解决方案中现在是包含一个工程其实它可以包含很多工程
# 2045.36 - 2047.64	:解决方案中还可以新建工程
# 2047.64 - 2050.24	:咱们就具体就不研究了
# 2050.24 - 2051.08	:具体不研究
# 2051.08 - 2053.08	:现在创建的项目
# 2053.08 - 2055.28	:咱们看到了这个项目名
# 2055.28 - 2057.04	:就是咱们所输入的project100
# 2057.04 - 2059.32	:这个项目也就是说这个工程
# 2059.32 - 2061.92	:那么位于 solution100
# 2061.92 - 2063.48	:解决方案之下
# 2063.48 - 2065.7	:那么好现在咱们大家看那么这个位于这个 solution100这个解决方案之下那么这个
# 2065.7 - 2067.26	:好
# 2067.26 - 2068.2	:现在呢
# 2068.2 - 2069.16	:咱们大家看
# 2069.16 - 2071.74	:在这个project100这个工程下
# 2071.74 - 2073.4	:咱们看这个原文件展开
# 2073.4 - 2075.48	:里边有一个最主要的文件
# 2075.48 - 2076.22	:叫project100
# 2076.22 - 2076.76	:双点
# 2076.76 - 2078.92	:就是这个原代码
# 2078.92 - 2079.96	:大家看到了
# 2079.96 - 2084.28	:这个VS217自动替咱们生成了这个project100.cpp
# 2084.28 - 2085.34	:这个主文件主的7++原文件然后咱们生成了这个Program 100.cpp这个主文件
# 2085.34 - 2087.08	:主的7++原文件
# 2087.08 - 2089.62	:然后呢这里边生成了一个代码
# 2089.62 - 2091.46	:生成一个代码之后呢
# 2091.46 - 2093.2	:那这里边这个代码啊
# 2093.2 - 2095.4	:可以说非常简单啊
# 2095.4 - 2097.92	:这个咱们可以把这些干掉
# 2097.92 - 2098.84	:这些没啥太大用
# 2098.84 - 2101.24	:然后这里边呢咱们编译一下
# 2101.24 - 2104.52	:生成解决方案这个菜单来编译一下
# 2104.52 - 2108.0	:因为这些代码都是他自动生成的
# 2108.0 - 2110.8	:这里按理来说应该return一下是吧
# 2110.8 - 2112.8	:咱们在这增补一下
# 2112.8 - 2116.8	:咱们在这增补一个return 0
# 2116.8 - 2119.8	:0是吧
# 2119.8 - 2121.3	:或者return 1是吧
# 2121.3 - 2123.2	:不管return 0 return 1
# 2123.2 - 2125.0	:因为这个卖还是整个乘以的执行入口这会有int返回1return1是吧不管return0,return1因为这个main函数
# 2125.0 - 2126.0	:整个程序的执行入口
# 2126.0 - 2129.0	:这会有int,返回1,return1
# 2129.0 - 2134.0	:那这样咱们再编译一下
# 2134.0 - 2137.0	:大家是否熟悉这个VS的操作
# 2137.0 - 2138.0	:Ctrl F5这个快捷键
# 2138.0 - 2141.0	:Ctrl F5是执行这个可执行程序
# 2141.0 - 2142.0	:是吧,执行可执行程序
# 2142.0 - 2144.0	:大家看到了显示一个hello world
# 2144.0 - 2145.6	:那么Ctrl F5如果大家执行不了快�是吧执行可执行程序大家看到了显示一个hello world那么control f5
# 2145.6 - 2146.68	:如果大家执行不了
# 2146.68 - 2148.32	:快捷键如果不好使的话
# 2148.32 - 2150.04	:那么咱们可以用什么生成
# 2150.04 - 2151.28	:这块有一个大家注意生成
# 2151.28 - 2152.36	:这个菜单有一个
# 2152.36 - 2155.8	:这个不在这在这
# 2155.8 - 2157.96	:调试菜单里有一个开始执行
# 2157.96 - 2159.16	:control f5也一样
# 2159.16 - 2161.52	:也能把这个程序执行起来
# 2161.52 - 2163.36	:这个效果跟control f5是一样的
# 2163.36 - 2164.08	:执行完了之后
# 2164.08 - 2165.52	:大家就看到了出了一个黑窗口
# 2165.52 - 2166.2	:是吧
# 2166.2 - 2168.02	:这个黑窗口里边显示Hello World
# 2168.02 - 2171.0	:这样现在就表示整个程序执行成功了
# 2171.0 - 2172.46	:这执行成功了
# 2172.46 - 2174.94	:因为当前咱们这个代码中只有一个面函数
# 2174.94 - 2176.0	:然后呢
# 2176.0 - 2177.78	:只有这个显示一行Hello World
# 2177.78 - 2180.6	:其他的也没干什么实际有益的事
# 2180.6 - 2183.72	:所以这个程序现在是编译成功
# 2183.72 - 2186.88	:这个达到了我们演示的效果大家看生成生成解决方案看编译成功达到了我们演示的效果
# 2186.88 - 2189.72	:大家看生成解决方案看编译成没成功
# 2189.72 - 2191.06	:生成解决方案的时候
# 2191.06 - 2192.04	:你等他一下
# 2192.04 - 2194.44	:他会提示你生成成功
# 2194.44 - 2197.24	:这个就表示咱们这个项目生成成功了
# 2197.24 - 2198.42	:这就行了
# 2198.42 - 2200.9	:咱们整个项目或者说这个工程
# 2200.9 - 2202.36	:咱们就搭建起来了
# 2202.36 - 2204.7	:下节课咱们或者是以后
# 2204.7 - 2205.8	:咱们要演示的时候咱们就要在这里起来了啊下节课咱们或者是以后咱们要演示的时候
# 2205.8 - 2209.5	:咱们就要在这里边来写代码来进行演示啊
# 2209.5 - 2210.28	:好
# 2210.28 - 2211.52	:那从下节课呀
# 2211.52 - 2216.34	:咱们就真正的进入到这个西加加对象模型啊
# 2216.34 - 2219.96	:这门课程的这个正式的讲解中去啊
# 2219.96 - 2221.98	:老师建议大家最起码啊
# 2221.98 - 2223.7	:把这个VS这个啊
# 2223.7 - 2226.16	:这个开发环境咱们要安装好
# 2226.16 - 2229.54	:必定咱们讲解的内容
# 2229.54 - 2231.58	:如果大家能够亲自的
# 2231.58 - 2233.66	:不光是听不光是出耳的听
# 2233.66 - 2237.36	:如果大家能够亲自的实操和演示一遍的话
# 2237.36 - 2240.06	:那学习效果可能是好上不少
# 2240.06 - 2242.96	:建议大家都能够亲自的演练
# 2242.96 - 2245.34	:随着老师的课程亲自实操
# 2245.34 - 2246.14	:好
# 2246.14 - 2247.74	:这节课咱们就讲到这
# 2247.74 - 2248.9	:谢谢大家收看
# 2248.9 - 2250.46	:咱们下节课再见
